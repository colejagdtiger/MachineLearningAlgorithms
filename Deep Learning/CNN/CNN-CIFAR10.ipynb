# %% [markdown]
# **Import** *and* setup some auxiliary functions

# %%
# Don't edit this cell
import os
import timeit
import time
import numpy as np
from collections import OrderedDict
from pprint import pformat
from tqdm import tqdm
from google.colab import drive

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data.sampler import *
from torchvision import transforms, datasets

torch.multiprocessing.set_sharing_strategy('file_system')
cudnn.benchmark = True

# %%
class Net(nn.Module):
  """
  CNN Net Class
  # 6 Convulation layers   
  # 5 Fully connected Layers
  # Batch Normalization done for Convulation layers 2 and 3
  # Xavier Initialization Used
  # Max Pooling with stride 2 used
  # Dropout Used

  Params : nn.Module
  
  """
  def __init__(self):
    """
    Constructor Class
    Definition of the CNN Net we are using and all the layers
    All convolution layers weights are Xavier Initialized

    Parameters : None

    Return : None
    """
    super(Net, self).__init__()  

    #CL 1 
    self.conv1 = nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv1.weight)

    # CL 2
    self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv2.weight)
    self.conv2_bn = nn.BatchNorm2d(16)

    # CL 3
    self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv3.weight)
    self.conv3_bn = nn.BatchNorm2d(32)

    # CL 4
    self.conv4 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv4.weight)
    self.conv4_bn = nn.BatchNorm2d(64)

    # CL 5
    self.conv5 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv5.weight)
    self.conv5_bn = nn.BatchNorm2d(128)

    # CL 6
    self.conv6 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1)
    torch.nn.init.xavier_uniform_(self.conv6.weight)
    self.conv6_bn = nn.BatchNorm2d(256)

    # Droput and Pooling Layer
    self.Dropout = nn.Dropout(0.2)
    self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    # Fully connected Layers

    # FC1
    self.fc1 = nn.Linear(in_features = 256 * 8 * 8, out_features=1024)
    torch.nn.init.xavier_uniform_(self.fc1.weight)

    # FC2
    self.fc2 = nn.Linear(in_features= 1024, out_features = 512)
    torch.nn.init.xavier_uniform_(self.fc2.weight)

    #FC3
    self.fc3 = nn.Linear(in_features= 512, out_features = 256)
    torch.nn.init.xavier_uniform_(self.fc3.weight)

    #FC4
    self.fc4 = nn.Linear(in_features= 256, out_features = 128)
    torch.nn.init.xavier_uniform_(self.fc4.weight)

    #FC5
    self.fc5 = nn.Linear(in_features = 128, out_features = 10)
    torch.nn.init.xavier_uniform_(self.fc5.weight)

    # Skip Connection Layer
    self.skip = nn.Identity()


  def forward(self, x):
    """
    Forward function
    Passes the layers to the activation functions
    Pooling is done 
    Skip connection for conv 2
    Dropout is used 
    Last layer doesn't use an activation function 

    Parameters : x

    Return : x
    """
    # CONV 1 - RELU - POOL - DROPOUT(0.2)
    x = self.pool(F.relu(self.conv1(x))) 
    x = self.Dropout(x)

    # CONV 2 - RELU - SKIP
    x = F.relu(self.conv2(x))
    x = x + self.skip(x)

    # CONV 3 - RELU - POOL
    x = self.pool(F.relu(self.conv3(x)))

    # CONV 4 - RELU - DROPOUT
    x = F.relu(self.conv4(x)) 
    x = self.Dropout(x)

    # CONV 5 - RELU
    x = F.relu(self.conv5(x))

    # CONV 6 - RELU 
    x = F.relu(self.conv6(x))

    # Reshape 
    x = x.view(-1, 256 * 8 * 8) 

    # FC 1 - RELU
    x = F.relu(self.fc1(x))

    # FC 2 - RELU - DROPOUT(0.2)
    x = F.relu(self.fc2(x))
    x = self.Dropout(x)

    # FC 3 - RELU
    x = F.relu(self.fc3(x))

    # FC 4 - RELU
    x = F.relu(self.fc4(x))

    # FC 5
    x = self.fc5(x)
    
    return x

# %%
def load_data(config):
    """
    Load cifar-10 dataset using torchvision, take the last 5k of the training data to be validation data 
    torch.utils.data.Subset was used to get the particular subset ie : 
    Accepts a generator hence why the range(0,number, 1) was used 
        1 - 45000 images for the training set
        2 - The last 5000 images for the validation set
    After that the torch.utils.data.DataLoader was used to load the datasets 
    The batch size that was defined above was used and shuffle = True as each time the dataset is reshuffled at every epoch

    Parameters: config

    Returns : train_dataloader, valid_dataloader, test_dataloader
    """
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    # Get the datasets 
    CIFAR10_training = datasets.CIFAR10("/CIFAR10_dataset/",train=True, download=True, transform = transform_train)
    CIFAR10_test = datasets.CIFAR10("/CIFAR10_dataset/",train=False, download=True, transform = transform_test)

    # Get the various subsets in the dataset
    CIFAR10_training_dataset = torch.utils.data.Subset(CIFAR10_training,range(0, 45000, 1))
    CIFAR10_validation_dataset = torch.utils.data.Subset(CIFAR10_training,range(45000, 50000, 1))

    # Define the dataloaders that are going to be used for the model
    # num_workers set to 0 as the main process should load the dataloaders compared to many subprocess which could increase time but is more efficient
    # Batch_size for the test dataloader was set to 1 as mentioned by the assignment
    train_dataloader  = torch.utils.data.DataLoader(CIFAR10_training_dataset, batch_size=config["batch_size"], shuffle=True, num_workers=0)
    valid_dataloader  = torch.utils.data.DataLoader(CIFAR10_validation_dataset, batch_size=config["batch_size"], shuffle=True, num_workers=0)
    test_dataloader = torch.utils.data.DataLoader(CIFAR10_test, batch_size=1, shuffle=True, num_workers=0)
   
    return train_dataloader, valid_dataloader, test_dataloader

# %%
def train(trainloader, validloader, device, config):
    """
    This function trains and validates the model on the dataset
    Learning Rate Annealing was used

    Paramaters: trainloader, validloader, device, config

    Returns: model
    """
    # Initialize the variables
    log_interval = 100
    correct = 0
    validation_loss = 0

    # Define the Model
    model = Net().to(device)

    # Define the cross entropy loss function
    criterion = nn.CrossEntropyLoss()

    # Train the model
    for epoch in range(config['num_epochs']):   
      if epoch <= 10:
          # Define the optimizer and using Adam set the parameters
          optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'], weight_decay=config['regular_constant'])
      elif epoch > 10 and epoch < 50:
          # Define the optimizer and using Adam do Learning Rate Annealing 
          optimizer = torch.optim.Adam(model.parameters(), lr=config['lr']/10, weight_decay=config['regular_constant']) 
      else:
          # Define the optimizer and using Adam do Learning Rate Annealing 
          optimizer = torch.optim.Adam(model.parameters(), lr=config['lr']/50, weight_decay=config['regular_constant']) 
      model.train()
      for batch_index, (images, labels) in enumerate(trainloader): 

          # convert from cpu to gpu
          images = images.to(device) 
          labels = labels.to(device)

          # Clear out the gradients in every call 
          # Else pytorch accumulates it every subsequent call 
          # If we dont use .zero_grad() we wont converge to the required minima
          optimizer.zero_grad()

          # find the output prediction 
          output = model(images)

          # Cross Entropy loss is calculated
          # Regularization is already added in our optimizer 
          # Weight Decay = L2 Regularization
          loss = criterion(output, labels) 
          
          # Back Progragation
          loss.backward()

          # Gradient Descent
          optimizer.step()

          # For each log interval print out the Training details ie : Epoch, Loss 
          # .format formats the output in the specific way we want it to be and 0.6f means 6 values after the decimal
          if (batch_index % log_interval) == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_index * len(images), len(trainloader.dataset),
            100. * batch_index / len(trainloader), loss.item()))
        
      # validation 

      # Set all the operations to have no gradient
      with torch.no_grad():
        validation_loss = 0
        correct = 0
        for images, labels in validloader:

          # Convert from cpu to gpu
          images = images.to(device)
          labels = labels.to(device)

          # Find the output prediction 
          output = model(images)

          # get the max element from the predictions 
          index, predictions = torch.max(output.data, 1)

          # Find the loss
          validation_loss += F.nll_loss(output, labels, size_average=False).item()

          # Find the validation loss hence 
          # Find the total number of correct predictions
          correct += (predictions == labels).sum().item()      

        # Find the mean validation accuracy loss
        validation_loss /= len(validloader.dataset)
        print('\nValidation set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        validation_loss, correct, len(validloader.dataset),
        100. * correct / len(validloader.dataset)))
                  
    return model

# %%
def save_model_colab_for_submission(model):  # if you are running on colab
  drive.mount('/content/gdrive/', force_remount=True)
  torch.save(model.to(torch.device("cpu")), '/content/gdrive/My Drive/model.pt') # you will find the model in your home drive
  
def save_model_local_for_submission(model):  # if you are running on your local machine
  torch.save(model.to(torch.device("cpu")), 'model.pt')

# %%
def test(net, testloader, device):
  """
  This function tests the CNN on the testdataset
  Passes the testdataset to the CNN model 

  Parameters: net, testloader, device

  Returns: accuracy,correct1,total1

  """
  
  # Initialize the variables
  correct = 0
  total = 0

  # net.eval() switches the net to work in eval mode instead of training mode.
  net.eval()

  # torch.no_grad() speeds up computation and deactivates it with the autograd engine
  # common practise of using both together to speed up 
  # Reference : https://discuss.pytorch.org/t/model-eval-vs-with-torch-no-grad/19615
  with torch.no_grad():

      # enumerate the test_dataset
      for images, labels in testloader:

          # convert from cpu to gpu
          images = images.to(device)
          labels = labels.to(device)

          # pass the images to the net and get the output predictions
          outputs = net(images)

          # Get the max element from the predictions
          # Get the total number of correct predictions
          # Get the total number of images in the testdataset
          indices, pred = torch.max(outputs.data, 1)  
          correct += (pred == labels).sum().item()
          total += labels.size(0)

  # Find the accuracy of the net 
  accuracy = 100. * correct / total

  return accuracy, correct, total

# %%
def run():
  # set parameters cifar10
  config = {
        'lr': 1e-3,
        'num_epochs': 200,
        'batch_size': 64,
        'num_classes': 10,
        'momentum':0.5,
        'regular_constant': 5e-4,
       }
    
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  
  train_dataloader, valid_dataloader, test_dataloader = load_data(config)
  
  model = train(train_dataloader, valid_dataloader, device, config)
  
  # Testing and saving for submission
  device = torch.device("cpu")

  """try:
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
  except AssertionError:
    os.mkdir('./checkpoint')"""

  torch.save(model.state_dict(),'./checkpoint/ckpt.pth')

  assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
  checkpoint = torch.load('./checkpoint/ckpt.pth')
  model.load_state_dict(checkpoint)
  model.eval()
  
  start_time = timeit.default_timer()
  test_acc, test_correct, test_total = test(model.to(device), test_dataloader, device)
  end_time = timeit.default_timer()
  test_time = (end_time - start_time)
  
  save_model_colab_for_submission(model)

  return test_acc, test_correct, test_time

# %% [markdown]
# Main loop. Run time and total score will be shown below.

# %%
# Don't edit this cell
def compute_score(acc, min_thres=65, max_thres=8):
  # Your Score thresholds
  if acc <= min_thres:
      base_score = 0.0
  elif acc >= max_thres:
      base_score = 100.0
  else:
      base_score = float(acc - min_thres) / (max_thres - min_thres) * 100
  return base_score

def main():
    
    accuracy, correct, run_time = run()
    
    score = compute_score(accuracy)
    
    result = OrderedDict(correct=correct,
                         accuracy=accuracy,
                         run_time=run_time,
                         score=score)
  
    with open('result.txt', 'w') as f:
        f.writelines(pformat(result, indent=4))
    print("\nResult:\n", pformat(result, indent=4))


main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train Epoch: 0 [0/45000 (0%)]	Loss: 2.313779
# Train Epoch: 0 [6400/45000 (14%)]	Loss: 2.064102
# Train Epoch: 0 [12800/45000 (28%)]	Loss: 2.026789
# Train Epoch: 0 [19200/45000 (43%)]	Loss: 1.902846
# Train Epoch: 0 [25600/45000 (57%)]	Loss: 1.864548
# Train Epoch: 0 [32000/45000 (71%)]	Loss: 1.617925
# Train Epoch: 0 [38400/45000 (85%)]	Loss: 1.703637
# Train Epoch: 0 [44800/45000 (99%)]	Loss: 1.708393
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Validation set: Avg. loss: -1.4765, Accuracy: 1762/5000 (35%)
#
# Train Epoch: 1 [0/45000 (0%)]	Loss: 1.587562
# Train Epoch: 1 [6400/45000 (14%)]	Loss: 1.451142
# Train Epoch: 1 [12800/45000 (28%)]	Loss: 1.555712
# Train Epoch: 1 [19200/45000 (43%)]	Loss: 1.386850
# Train Epoch: 1 [25600/45000 (57%)]	Loss: 1.347966
# Train Epoch: 1 [32000/45000 (71%)]	Loss: 1.566078
# Train Epoch: 1 [38400/45000 (85%)]	Loss: 1.693886
# Train Epoch: 1 [44800/45000 (99%)]	Loss: 1.715047
#
# Validation set: Avg. loss: -1.9276, Accuracy: 2205/5000 (44%)
#
# Train Epoch: 2 [0/45000 (0%)]	Loss: 1.687870
# Train Epoch: 2 [6400/45000 (14%)]	Loss: 1.318055
# Train Epoch: 2 [12800/45000 (28%)]	Loss: 1.474167
# Train Epoch: 2 [19200/45000 (43%)]	Loss: 1.452633
# Train Epoch: 2 [25600/45000 (57%)]	Loss: 1.543798
# Train Epoch: 2 [32000/45000 (71%)]	Loss: 1.324542
# Train Epoch: 2 [38400/45000 (85%)]	Loss: 1.529662
# Train Epoch: 2 [44800/45000 (99%)]	Loss: 1.273074
#
# Validation set: Avg. loss: -2.3907, Accuracy: 2313/5000 (46%)
#
# Train Epoch: 3 [0/45000 (0%)]	Loss: 1.452822
# Train Epoch: 3 [6400/45000 (14%)]	Loss: 1.426196
# Train Epoch: 3 [12800/45000 (28%)]	Loss: 1.413057
# Train Epoch: 3 [19200/45000 (43%)]	Loss: 1.372340
# Train Epoch: 3 [25600/45000 (57%)]	Loss: 1.233887
# Train Epoch: 3 [32000/45000 (71%)]	Loss: 1.269759
# Train Epoch: 3 [38400/45000 (85%)]	Loss: 1.429344
# Train Epoch: 3 [44800/45000 (99%)]	Loss: 1.070521
#
# Validation set: Avg. loss: -2.2158, Accuracy: 2561/5000 (51%)
#
# Train Epoch: 4 [0/45000 (0%)]	Loss: 1.440614
# Train Epoch: 4 [6400/45000 (14%)]	Loss: 1.206594
# Train Epoch: 4 [12800/45000 (28%)]	Loss: 1.293447
# Train Epoch: 4 [19200/45000 (43%)]	Loss: 1.244880
# Train Epoch: 4 [25600/45000 (57%)]	Loss: 1.210884
# Train Epoch: 4 [32000/45000 (71%)]	Loss: 1.349108
# Train Epoch: 4 [38400/45000 (85%)]	Loss: 1.304973
# Train Epoch: 4 [44800/45000 (99%)]	Loss: 1.181086
#
# Validation set: Avg. loss: -2.3832, Accuracy: 2712/5000 (54%)
#
# Train Epoch: 5 [0/45000 (0%)]	Loss: 1.346127
# Train Epoch: 5 [6400/45000 (14%)]	Loss: 1.120030
# Train Epoch: 5 [12800/45000 (28%)]	Loss: 1.504312
# Train Epoch: 5 [19200/45000 (43%)]	Loss: 1.370556
# Train Epoch: 5 [25600/45000 (57%)]	Loss: 1.423093
# Train Epoch: 5 [32000/45000 (71%)]	Loss: 1.181173
# Train Epoch: 5 [38400/45000 (85%)]	Loss: 1.163595
# Train Epoch: 5 [44800/45000 (99%)]	Loss: 0.897452
#
# Validation set: Avg. loss: -2.4887, Accuracy: 2777/5000 (56%)
#
# Train Epoch: 6 [0/45000 (0%)]	Loss: 1.067417
# Train Epoch: 6 [6400/45000 (14%)]	Loss: 1.415898
# Train Epoch: 6 [12800/45000 (28%)]	Loss: 1.169072
# Train Epoch: 6 [19200/45000 (43%)]	Loss: 1.204298
# Train Epoch: 6 [25600/45000 (57%)]	Loss: 1.214844
# Train Epoch: 6 [32000/45000 (71%)]	Loss: 0.904737
# Train Epoch: 6 [38400/45000 (85%)]	Loss: 1.451317
# Train Epoch: 6 [44800/45000 (99%)]	Loss: 1.221775
#
# Validation set: Avg. loss: -2.5439, Accuracy: 2886/5000 (58%)
#
# Train Epoch: 7 [0/45000 (0%)]	Loss: 0.981344
# Train Epoch: 7 [6400/45000 (14%)]	Loss: 1.038294
# Train Epoch: 7 [12800/45000 (28%)]	Loss: 1.324306
# Train Epoch: 7 [19200/45000 (43%)]	Loss: 1.056025
# Train Epoch: 7 [25600/45000 (57%)]	Loss: 1.295137
# Train Epoch: 7 [32000/45000 (71%)]	Loss: 1.236975
# Train Epoch: 7 [38400/45000 (85%)]	Loss: 1.242256
# Train Epoch: 7 [44800/45000 (99%)]	Loss: 1.461621
#
# Validation set: Avg. loss: -2.5552, Accuracy: 2924/5000 (58%)
#
# Train Epoch: 8 [0/45000 (0%)]	Loss: 1.273865
# Train Epoch: 8 [6400/45000 (14%)]	Loss: 1.057380
# Train Epoch: 8 [12800/45000 (28%)]	Loss: 1.555557
# Train Epoch: 8 [19200/45000 (43%)]	Loss: 1.159041
# Train Epoch: 8 [25600/45000 (57%)]	Loss: 0.929700
# Train Epoch: 8 [32000/45000 (71%)]	Loss: 1.185200
# Train Epoch: 8 [38400/45000 (85%)]	Loss: 1.101509
# Train Epoch: 8 [44800/45000 (99%)]	Loss: 1.139071
#
# Validation set: Avg. loss: -2.7560, Accuracy: 3075/5000 (62%)
#
# Train Epoch: 9 [0/45000 (0%)]	Loss: 0.875358
# Train Epoch: 9 [6400/45000 (14%)]	Loss: 1.223347
# Train Epoch: 9 [12800/45000 (28%)]	Loss: 1.009972
# Train Epoch: 9 [19200/45000 (43%)]	Loss: 1.030601
# Train Epoch: 9 [25600/45000 (57%)]	Loss: 0.854003
# Train Epoch: 9 [32000/45000 (71%)]	Loss: 1.105510
# Train Epoch: 9 [38400/45000 (85%)]	Loss: 1.223393
# Train Epoch: 9 [44800/45000 (99%)]	Loss: 1.025943
#
# Validation set: Avg. loss: -2.8981, Accuracy: 3099/5000 (62%)
#
# Train Epoch: 10 [0/45000 (0%)]	Loss: 1.080284
# Train Epoch: 10 [6400/45000 (14%)]	Loss: 0.924915
# Train Epoch: 10 [12800/45000 (28%)]	Loss: 0.971090
# Train Epoch: 10 [19200/45000 (43%)]	Loss: 1.214846
# Train Epoch: 10 [25600/45000 (57%)]	Loss: 1.064752
# Train Epoch: 10 [32000/45000 (71%)]	Loss: 1.226413
# Train Epoch: 10 [38400/45000 (85%)]	Loss: 0.993048
# Train Epoch: 10 [44800/45000 (99%)]	Loss: 1.169267
#
# Validation set: Avg. loss: -2.9824, Accuracy: 3173/5000 (63%)
#
# Train Epoch: 11 [0/45000 (0%)]	Loss: 1.043195
# Train Epoch: 11 [6400/45000 (14%)]	Loss: 0.866309
# Train Epoch: 11 [12800/45000 (28%)]	Loss: 1.106633
# Train Epoch: 11 [19200/45000 (43%)]	Loss: 1.074295
# Train Epoch: 11 [25600/45000 (57%)]	Loss: 0.968634
# Train Epoch: 11 [32000/45000 (71%)]	Loss: 0.857590
# Train Epoch: 11 [38400/45000 (85%)]	Loss: 1.116457
# Train Epoch: 11 [44800/45000 (99%)]	Loss: 0.868715
#
# Validation set: Avg. loss: -3.2133, Accuracy: 3303/5000 (66%)
#
# Train Epoch: 12 [0/45000 (0%)]	Loss: 0.943312
# Train Epoch: 12 [6400/45000 (14%)]	Loss: 0.900297
# Train Epoch: 12 [12800/45000 (28%)]	Loss: 1.065193
# Train Epoch: 12 [19200/45000 (43%)]	Loss: 0.908761
# Train Epoch: 12 [25600/45000 (57%)]	Loss: 1.229449
# Train Epoch: 12 [32000/45000 (71%)]	Loss: 0.746737
# Train Epoch: 12 [38400/45000 (85%)]	Loss: 0.905732
# Train Epoch: 12 [44800/45000 (99%)]	Loss: 0.956796
#
# Validation set: Avg. loss: -3.2597, Accuracy: 3290/5000 (66%)
#
# Train Epoch: 13 [0/45000 (0%)]	Loss: 1.278282
# Train Epoch: 13 [6400/45000 (14%)]	Loss: 0.951347
# Train Epoch: 13 [12800/45000 (28%)]	Loss: 0.913789
# Train Epoch: 13 [19200/45000 (43%)]	Loss: 1.197632
# Train Epoch: 13 [25600/45000 (57%)]	Loss: 0.943789
# Train Epoch: 13 [32000/45000 (71%)]	Loss: 1.061906
# Train Epoch: 13 [38400/45000 (85%)]	Loss: 1.047832
# Train Epoch: 13 [44800/45000 (99%)]	Loss: 0.838755
#
# Validation set: Avg. loss: -3.4706, Accuracy: 3354/5000 (67%)
#
# Train Epoch: 14 [0/45000 (0%)]	Loss: 0.965067
# Train Epoch: 14 [6400/45000 (14%)]	Loss: 1.060175
# Train Epoch: 14 [12800/45000 (28%)]	Loss: 0.950295
# Train Epoch: 14 [19200/45000 (43%)]	Loss: 0.958336
# Train Epoch: 14 [25600/45000 (57%)]	Loss: 0.771452
# Train Epoch: 14 [32000/45000 (71%)]	Loss: 0.843855
# Train Epoch: 14 [38400/45000 (85%)]	Loss: 1.046679
# Train Epoch: 14 [44800/45000 (99%)]	Loss: 0.865486
#
# Validation set: Avg. loss: -3.3753, Accuracy: 3355/5000 (67%)
#
# Train Epoch: 15 [0/45000 (0%)]	Loss: 0.947410
# Train Epoch: 15 [6400/45000 (14%)]	Loss: 0.991057
# Train Epoch: 15 [12800/45000 (28%)]	Loss: 0.916637
# Train Epoch: 15 [19200/45000 (43%)]	Loss: 0.641841
# Train Epoch: 15 [25600/45000 (57%)]	Loss: 0.993885
# Train Epoch: 15 [32000/45000 (71%)]	Loss: 0.797648
# Train Epoch: 15 [38400/45000 (85%)]	Loss: 1.174313
# Train Epoch: 15 [44800/45000 (99%)]	Loss: 0.713847
#
# Validation set: Avg. loss: -3.3558, Accuracy: 3372/5000 (67%)
#
# Train Epoch: 16 [0/45000 (0%)]	Loss: 0.966852
# Train Epoch: 16 [6400/45000 (14%)]	Loss: 1.053126
# Train Epoch: 16 [12800/45000 (28%)]	Loss: 0.921130
# Train Epoch: 16 [19200/45000 (43%)]	Loss: 0.747793
# Train Epoch: 16 [25600/45000 (57%)]	Loss: 1.012051
# Train Epoch: 16 [32000/45000 (71%)]	Loss: 0.839723
# Train Epoch: 16 [38400/45000 (85%)]	Loss: 1.134465
# Train Epoch: 16 [44800/45000 (99%)]	Loss: 0.971112
#
# Validation set: Avg. loss: -3.4851, Accuracy: 3397/5000 (68%)
#
# Train Epoch: 17 [0/45000 (0%)]	Loss: 1.089342
# Train Epoch: 17 [6400/45000 (14%)]	Loss: 0.919399
# Train Epoch: 17 [12800/45000 (28%)]	Loss: 1.042071
# Train Epoch: 17 [19200/45000 (43%)]	Loss: 1.120231
# Train Epoch: 17 [25600/45000 (57%)]	Loss: 0.863651
# Train Epoch: 17 [32000/45000 (71%)]	Loss: 0.871215
# Train Epoch: 17 [38400/45000 (85%)]	Loss: 0.925380
# Train Epoch: 17 [44800/45000 (99%)]	Loss: 0.667384
#
# Validation set: Avg. loss: -3.4080, Accuracy: 3369/5000 (67%)
#
# Train Epoch: 18 [0/45000 (0%)]	Loss: 0.812342
# Train Epoch: 18 [6400/45000 (14%)]	Loss: 0.636563
# Train Epoch: 18 [12800/45000 (28%)]	Loss: 0.868239
# Train Epoch: 18 [19200/45000 (43%)]	Loss: 0.865309
# Train Epoch: 18 [25600/45000 (57%)]	Loss: 0.860042
# Train Epoch: 18 [32000/45000 (71%)]	Loss: 0.663833
# Train Epoch: 18 [38400/45000 (85%)]	Loss: 0.633970
# Train Epoch: 18 [44800/45000 (99%)]	Loss: 0.723583
#
# Validation set: Avg. loss: -3.4290, Accuracy: 3428/5000 (69%)
#
# Train Epoch: 19 [0/45000 (0%)]	Loss: 0.898540
# Train Epoch: 19 [6400/45000 (14%)]	Loss: 0.857880
# Train Epoch: 19 [12800/45000 (28%)]	Loss: 1.110101
# Train Epoch: 19 [19200/45000 (43%)]	Loss: 0.616976
# Train Epoch: 19 [25600/45000 (57%)]	Loss: 0.818876
# Train Epoch: 19 [32000/45000 (71%)]	Loss: 0.676038
# Train Epoch: 19 [38400/45000 (85%)]	Loss: 1.031922
# Train Epoch: 19 [44800/45000 (99%)]	Loss: 0.865615
#
# Validation set: Avg. loss: -3.5061, Accuracy: 3436/5000 (69%)
#
# Train Epoch: 20 [0/45000 (0%)]	Loss: 0.828865
# Train Epoch: 20 [6400/45000 (14%)]	Loss: 0.835225
# Train Epoch: 20 [12800/45000 (28%)]	Loss: 0.938082
# Train Epoch: 20 [19200/45000 (43%)]	Loss: 0.663545
# Train Epoch: 20 [25600/45000 (57%)]	Loss: 1.059706
# Train Epoch: 20 [32000/45000 (71%)]	Loss: 1.193418
# Train Epoch: 20 [38400/45000 (85%)]	Loss: 0.718951
# Train Epoch: 20 [44800/45000 (99%)]	Loss: 0.824575
#
# Validation set: Avg. loss: -3.4492, Accuracy: 3416/5000 (68%)
#
# Train Epoch: 21 [0/45000 (0%)]	Loss: 0.940944
# Train Epoch: 21 [6400/45000 (14%)]	Loss: 0.742545
# Train Epoch: 21 [12800/45000 (28%)]	Loss: 0.822503
# Train Epoch: 21 [19200/45000 (43%)]	Loss: 0.831050
# Train Epoch: 21 [25600/45000 (57%)]	Loss: 0.894102
# Train Epoch: 21 [32000/45000 (71%)]	Loss: 1.091637
# Train Epoch: 21 [38400/45000 (85%)]	Loss: 0.989381
# Train Epoch: 21 [44800/45000 (99%)]	Loss: 0.719264
#
# Validation set: Avg. loss: -3.5179, Accuracy: 3449/5000 (69%)
#
# Train Epoch: 22 [0/45000 (0%)]	Loss: 0.774058
# Train Epoch: 22 [6400/45000 (14%)]	Loss: 0.822476
# Train Epoch: 22 [12800/45000 (28%)]	Loss: 0.856004
# Train Epoch: 22 [19200/45000 (43%)]	Loss: 0.875702
# Train Epoch: 22 [25600/45000 (57%)]	Loss: 0.674502
# Train Epoch: 22 [32000/45000 (71%)]	Loss: 0.867893
# Train Epoch: 22 [38400/45000 (85%)]	Loss: 1.016821
# Train Epoch: 22 [44800/45000 (99%)]	Loss: 0.768520
#
# Validation set: Avg. loss: -3.3783, Accuracy: 3440/5000 (69%)
#
# Train Epoch: 23 [0/45000 (0%)]	Loss: 0.895895
# Train Epoch: 23 [6400/45000 (14%)]	Loss: 0.964935
# Train Epoch: 23 [12800/45000 (28%)]	Loss: 0.885660
# Train Epoch: 23 [19200/45000 (43%)]	Loss: 0.982539
# Train Epoch: 23 [25600/45000 (57%)]	Loss: 0.828105
# Train Epoch: 23 [32000/45000 (71%)]	Loss: 0.920603
# Train Epoch: 23 [38400/45000 (85%)]	Loss: 0.700750
# Train Epoch: 23 [44800/45000 (99%)]	Loss: 0.871235
#
# Validation set: Avg. loss: -3.5190, Accuracy: 3477/5000 (70%)
#
# Train Epoch: 24 [0/45000 (0%)]	Loss: 0.973506
# Train Epoch: 24 [6400/45000 (14%)]	Loss: 0.977169
# Train Epoch: 24 [12800/45000 (28%)]	Loss: 0.992148
# Train Epoch: 24 [19200/45000 (43%)]	Loss: 0.752154
# Train Epoch: 24 [25600/45000 (57%)]	Loss: 0.945622
# Train Epoch: 24 [32000/45000 (71%)]	Loss: 0.786546
# Train Epoch: 24 [38400/45000 (85%)]	Loss: 0.738164
# Train Epoch: 24 [44800/45000 (99%)]	Loss: 0.673530
#
# Validation set: Avg. loss: -3.3855, Accuracy: 3425/5000 (68%)
#
# Train Epoch: 25 [0/45000 (0%)]	Loss: 0.844005
# Train Epoch: 25 [6400/45000 (14%)]	Loss: 0.790997
# Train Epoch: 25 [12800/45000 (28%)]	Loss: 0.776442
# Train Epoch: 25 [19200/45000 (43%)]	Loss: 0.627391
# Train Epoch: 25 [25600/45000 (57%)]	Loss: 0.737780
# Train Epoch: 25 [32000/45000 (71%)]	Loss: 0.687471
# Train Epoch: 25 [38400/45000 (85%)]	Loss: 0.928174
# Train Epoch: 25 [44800/45000 (99%)]	Loss: 0.782417
#
# Validation set: Avg. loss: -3.5700, Accuracy: 3549/5000 (71%)
#
# Train Epoch: 26 [0/45000 (0%)]	Loss: 0.889693
# Train Epoch: 26 [6400/45000 (14%)]	Loss: 0.915488
# Train Epoch: 26 [12800/45000 (28%)]	Loss: 0.842809
# Train Epoch: 26 [19200/45000 (43%)]	Loss: 1.063915
# Train Epoch: 26 [25600/45000 (57%)]	Loss: 0.847711
# Train Epoch: 26 [32000/45000 (71%)]	Loss: 0.885624
# Train Epoch: 26 [38400/45000 (85%)]	Loss: 0.757272
# Train Epoch: 26 [44800/45000 (99%)]	Loss: 0.869839
#
# Validation set: Avg. loss: -3.5178, Accuracy: 3453/5000 (69%)
#
# Train Epoch: 27 [0/45000 (0%)]	Loss: 0.796640
# Train Epoch: 27 [6400/45000 (14%)]	Loss: 0.803243
# Train Epoch: 27 [12800/45000 (28%)]	Loss: 0.925046
# Train Epoch: 27 [19200/45000 (43%)]	Loss: 0.816606
# Train Epoch: 27 [25600/45000 (57%)]	Loss: 0.786986
# Train Epoch: 27 [32000/45000 (71%)]	Loss: 0.876017
# Train Epoch: 27 [38400/45000 (85%)]	Loss: 0.875566
# Train Epoch: 27 [44800/45000 (99%)]	Loss: 1.058017
#
# Validation set: Avg. loss: -3.5325, Accuracy: 3477/5000 (70%)
#
# Train Epoch: 28 [0/45000 (0%)]	Loss: 0.785265
# Train Epoch: 28 [6400/45000 (14%)]	Loss: 0.858521
# Train Epoch: 28 [12800/45000 (28%)]	Loss: 0.832313
# Train Epoch: 28 [19200/45000 (43%)]	Loss: 0.783107
# Train Epoch: 28 [25600/45000 (57%)]	Loss: 0.849170
# Train Epoch: 28 [32000/45000 (71%)]	Loss: 1.125885
# Train Epoch: 28 [38400/45000 (85%)]	Loss: 0.815711
# Train Epoch: 28 [44800/45000 (99%)]	Loss: 0.690693
#
# Validation set: Avg. loss: -3.5048, Accuracy: 3517/5000 (70%)
#
# Train Epoch: 29 [0/45000 (0%)]	Loss: 0.710967
# Train Epoch: 29 [6400/45000 (14%)]	Loss: 0.835209
# Train Epoch: 29 [12800/45000 (28%)]	Loss: 0.806056
# Train Epoch: 29 [19200/45000 (43%)]	Loss: 0.991776
# Train Epoch: 29 [25600/45000 (57%)]	Loss: 0.784322
# Train Epoch: 29 [32000/45000 (71%)]	Loss: 0.864089
# Train Epoch: 29 [38400/45000 (85%)]	Loss: 0.810201
# Train Epoch: 29 [44800/45000 (99%)]	Loss: 0.747263
#
# Validation set: Avg. loss: -3.5421, Accuracy: 3540/5000 (71%)
#
# Train Epoch: 30 [0/45000 (0%)]	Loss: 0.812094
# Train Epoch: 30 [6400/45000 (14%)]	Loss: 0.745563
# Train Epoch: 30 [12800/45000 (28%)]	Loss: 1.079549
# Train Epoch: 30 [19200/45000 (43%)]	Loss: 0.931817
# Train Epoch: 30 [25600/45000 (57%)]	Loss: 0.857928
# Train Epoch: 30 [32000/45000 (71%)]	Loss: 0.980440
# Train Epoch: 30 [38400/45000 (85%)]	Loss: 0.863352
# Train Epoch: 30 [44800/45000 (99%)]	Loss: 0.897647
#
# Validation set: Avg. loss: -3.4658, Accuracy: 3531/5000 (71%)
#
# Train Epoch: 31 [0/45000 (0%)]	Loss: 0.724166
# Train Epoch: 31 [6400/45000 (14%)]	Loss: 0.816815
# Train Epoch: 31 [12800/45000 (28%)]	Loss: 0.827491
# Train Epoch: 31 [19200/45000 (43%)]	Loss: 0.936822
# Train Epoch: 31 [25600/45000 (57%)]	Loss: 0.738858
# Train Epoch: 31 [32000/45000 (71%)]	Loss: 0.748634
# Train Epoch: 31 [38400/45000 (85%)]	Loss: 0.665609
# Train Epoch: 31 [44800/45000 (99%)]	Loss: 0.748207
#
# Validation set: Avg. loss: -3.4496, Accuracy: 3527/5000 (71%)
#
# Train Epoch: 32 [0/45000 (0%)]	Loss: 0.866223
# Train Epoch: 32 [6400/45000 (14%)]	Loss: 0.756401
# Train Epoch: 32 [12800/45000 (28%)]	Loss: 0.534415
# Train Epoch: 32 [19200/45000 (43%)]	Loss: 0.821813
# Train Epoch: 32 [25600/45000 (57%)]	Loss: 0.847899
# Train Epoch: 32 [32000/45000 (71%)]	Loss: 1.030102
# Train Epoch: 32 [38400/45000 (85%)]	Loss: 0.816693
# Train Epoch: 32 [44800/45000 (99%)]	Loss: 0.893636
#
# Validation set: Avg. loss: -3.5545, Accuracy: 3577/5000 (72%)
#
# Train Epoch: 33 [0/45000 (0%)]	Loss: 0.773447
# Train Epoch: 33 [6400/45000 (14%)]	Loss: 0.666810
# Train Epoch: 33 [12800/45000 (28%)]	Loss: 0.756280
# Train Epoch: 33 [19200/45000 (43%)]	Loss: 0.656845
# Train Epoch: 33 [25600/45000 (57%)]	Loss: 0.936704
# Train Epoch: 33 [32000/45000 (71%)]	Loss: 0.601639
# Train Epoch: 33 [38400/45000 (85%)]	Loss: 1.002076
# Train Epoch: 33 [44800/45000 (99%)]	Loss: 0.784177
#
# Validation set: Avg. loss: -3.4049, Accuracy: 3591/5000 (72%)
#
# Train Epoch: 34 [0/45000 (0%)]	Loss: 0.656890
# Train Epoch: 34 [6400/45000 (14%)]	Loss: 0.817252
# Train Epoch: 34 [12800/45000 (28%)]	Loss: 0.787414
# Train Epoch: 34 [19200/45000 (43%)]	Loss: 0.838164
# Train Epoch: 34 [25600/45000 (57%)]	Loss: 0.805219
# Train Epoch: 34 [32000/45000 (71%)]	Loss: 0.749689
# Train Epoch: 34 [38400/45000 (85%)]	Loss: 0.810644
# Train Epoch: 34 [44800/45000 (99%)]	Loss: 1.025682
#
# Validation set: Avg. loss: -3.3796, Accuracy: 3571/5000 (71%)
#
# Train Epoch: 35 [0/45000 (0%)]	Loss: 0.672594
# Train Epoch: 35 [6400/45000 (14%)]	Loss: 0.877667
# Train Epoch: 35 [12800/45000 (28%)]	Loss: 0.878656
# Train Epoch: 35 [19200/45000 (43%)]	Loss: 0.702968
# Train Epoch: 35 [25600/45000 (57%)]	Loss: 0.771099
# Train Epoch: 35 [32000/45000 (71%)]	Loss: 0.750232
# Train Epoch: 35 [38400/45000 (85%)]	Loss: 0.671705
# Train Epoch: 35 [44800/45000 (99%)]	Loss: 0.800497
#
# Validation set: Avg. loss: -3.4322, Accuracy: 3586/5000 (72%)
#
# Train Epoch: 36 [0/45000 (0%)]	Loss: 0.794255
# Train Epoch: 36 [6400/45000 (14%)]	Loss: 0.803579
# Train Epoch: 36 [12800/45000 (28%)]	Loss: 0.949805
# Train Epoch: 36 [19200/45000 (43%)]	Loss: 0.670585
# Train Epoch: 36 [25600/45000 (57%)]	Loss: 0.814925
# Train Epoch: 36 [32000/45000 (71%)]	Loss: 0.754643
# Train Epoch: 36 [38400/45000 (85%)]	Loss: 0.712030
# Train Epoch: 36 [44800/45000 (99%)]	Loss: 0.870500
#
# Validation set: Avg. loss: -3.6375, Accuracy: 3585/5000 (72%)
#
# Train Epoch: 37 [0/45000 (0%)]	Loss: 0.635010
# Train Epoch: 37 [6400/45000 (14%)]	Loss: 0.753890
# Train Epoch: 37 [12800/45000 (28%)]	Loss: 0.857938
# Train Epoch: 37 [19200/45000 (43%)]	Loss: 0.856103
# Train Epoch: 37 [25600/45000 (57%)]	Loss: 0.770610
# Train Epoch: 37 [32000/45000 (71%)]	Loss: 0.731789
# Train Epoch: 37 [38400/45000 (85%)]	Loss: 0.736695
# Train Epoch: 37 [44800/45000 (99%)]	Loss: 0.832574
#
# Validation set: Avg. loss: -3.4637, Accuracy: 3578/5000 (72%)
#
# Train Epoch: 38 [0/45000 (0%)]	Loss: 0.852976
# Train Epoch: 38 [6400/45000 (14%)]	Loss: 0.847430
# Train Epoch: 38 [12800/45000 (28%)]	Loss: 0.878735
# Train Epoch: 38 [19200/45000 (43%)]	Loss: 0.770089
# Train Epoch: 38 [25600/45000 (57%)]	Loss: 0.859898
# Train Epoch: 38 [32000/45000 (71%)]	Loss: 0.904546
# Train Epoch: 38 [38400/45000 (85%)]	Loss: 0.967191
# Train Epoch: 38 [44800/45000 (99%)]	Loss: 0.697397
#
# Validation set: Avg. loss: -3.4295, Accuracy: 3638/5000 (73%)
#
# Train Epoch: 39 [0/45000 (0%)]	Loss: 0.742115
# Train Epoch: 39 [6400/45000 (14%)]	Loss: 1.189298
# Train Epoch: 39 [12800/45000 (28%)]	Loss: 0.558992
# Train Epoch: 39 [19200/45000 (43%)]	Loss: 0.901561
# Train Epoch: 39 [25600/45000 (57%)]	Loss: 0.884700
# Train Epoch: 39 [32000/45000 (71%)]	Loss: 0.484199
# Train Epoch: 39 [38400/45000 (85%)]	Loss: 0.819116
# Train Epoch: 39 [44800/45000 (99%)]	Loss: 0.784207
#
# Validation set: Avg. loss: -3.4676, Accuracy: 3574/5000 (71%)
#
# Train Epoch: 40 [0/45000 (0%)]	Loss: 0.794732
# Train Epoch: 40 [6400/45000 (14%)]	Loss: 0.707190
# Train Epoch: 40 [12800/45000 (28%)]	Loss: 0.801508
# Train Epoch: 40 [19200/45000 (43%)]	Loss: 0.592187
# Train Epoch: 40 [25600/45000 (57%)]	Loss: 0.779377
# Train Epoch: 40 [32000/45000 (71%)]	Loss: 0.787083
# Train Epoch: 40 [38400/45000 (85%)]	Loss: 0.721627
# Train Epoch: 40 [44800/45000 (99%)]	Loss: 0.816921
#
# Validation set: Avg. loss: -3.5269, Accuracy: 3623/5000 (72%)
#
# Train Epoch: 41 [0/45000 (0%)]	Loss: 0.822207
# Train Epoch: 41 [6400/45000 (14%)]	Loss: 0.869250
# Train Epoch: 41 [12800/45000 (28%)]	Loss: 0.939907
# Train Epoch: 41 [19200/45000 (43%)]	Loss: 1.004163
# Train Epoch: 41 [25600/45000 (57%)]	Loss: 0.677562
# Train Epoch: 41 [32000/45000 (71%)]	Loss: 0.518136
# Train Epoch: 41 [38400/45000 (85%)]	Loss: 0.795223
# Train Epoch: 41 [44800/45000 (99%)]	Loss: 0.830393
#
# Validation set: Avg. loss: -3.6382, Accuracy: 3664/5000 (73%)
#
# Train Epoch: 42 [0/45000 (0%)]	Loss: 0.644460
# Train Epoch: 42 [6400/45000 (14%)]	Loss: 0.904585
# Train Epoch: 42 [12800/45000 (28%)]	Loss: 0.685775
# Train Epoch: 42 [19200/45000 (43%)]	Loss: 0.654721
# Train Epoch: 42 [25600/45000 (57%)]	Loss: 0.870051
# Train Epoch: 42 [32000/45000 (71%)]	Loss: 0.835877
# Train Epoch: 42 [38400/45000 (85%)]	Loss: 0.654535
# Train Epoch: 42 [44800/45000 (99%)]	Loss: 0.795546
#
# Validation set: Avg. loss: -3.5215, Accuracy: 3607/5000 (72%)
#
# Train Epoch: 43 [0/45000 (0%)]	Loss: 0.732790
# Train Epoch: 43 [6400/45000 (14%)]	Loss: 0.600561
# Train Epoch: 43 [12800/45000 (28%)]	Loss: 0.810914
# Train Epoch: 43 [19200/45000 (43%)]	Loss: 0.826045
# Train Epoch: 43 [25600/45000 (57%)]	Loss: 0.648327
# Train Epoch: 43 [32000/45000 (71%)]	Loss: 0.847598
# Train Epoch: 43 [38400/45000 (85%)]	Loss: 0.571473
# Train Epoch: 43 [44800/45000 (99%)]	Loss: 0.959713
#
# Validation set: Avg. loss: -3.5172, Accuracy: 3647/5000 (73%)
#
# Train Epoch: 44 [0/45000 (0%)]	Loss: 0.746839
# Train Epoch: 44 [6400/45000 (14%)]	Loss: 0.651729
# Train Epoch: 44 [12800/45000 (28%)]	Loss: 0.782884
# Train Epoch: 44 [19200/45000 (43%)]	Loss: 0.528605
# Train Epoch: 44 [25600/45000 (57%)]	Loss: 0.775634
# Train Epoch: 44 [32000/45000 (71%)]	Loss: 0.789698
# Train Epoch: 44 [38400/45000 (85%)]	Loss: 1.005861
# Train Epoch: 44 [44800/45000 (99%)]	Loss: 0.581169
#
# Validation set: Avg. loss: -3.5089, Accuracy: 3666/5000 (73%)
#
# Train Epoch: 45 [0/45000 (0%)]	Loss: 0.589622
# Train Epoch: 45 [6400/45000 (14%)]	Loss: 0.681132
# Train Epoch: 45 [12800/45000 (28%)]	Loss: 0.974267
# Train Epoch: 45 [19200/45000 (43%)]	Loss: 0.691390
# Train Epoch: 45 [25600/45000 (57%)]	Loss: 0.516328
# Train Epoch: 45 [32000/45000 (71%)]	Loss: 0.529659
# Train Epoch: 45 [38400/45000 (85%)]	Loss: 0.397032
# Train Epoch: 45 [44800/45000 (99%)]	Loss: 0.814310
#
# Validation set: Avg. loss: -3.4800, Accuracy: 3637/5000 (73%)
#
# Train Epoch: 46 [0/45000 (0%)]	Loss: 0.902731
# Train Epoch: 46 [6400/45000 (14%)]	Loss: 0.634040
# Train Epoch: 46 [12800/45000 (28%)]	Loss: 0.779321
# Train Epoch: 46 [19200/45000 (43%)]	Loss: 0.670181
# Train Epoch: 46 [25600/45000 (57%)]	Loss: 0.780032
# Train Epoch: 46 [32000/45000 (71%)]	Loss: 0.756812
# Train Epoch: 46 [38400/45000 (85%)]	Loss: 0.803772
# Train Epoch: 46 [44800/45000 (99%)]	Loss: 1.026460
#
# Validation set: Avg. loss: -3.5354, Accuracy: 3682/5000 (74%)
#
# Train Epoch: 47 [0/45000 (0%)]	Loss: 0.834444
# Train Epoch: 47 [6400/45000 (14%)]	Loss: 0.595320
# Train Epoch: 47 [12800/45000 (28%)]	Loss: 0.768809
# Train Epoch: 47 [19200/45000 (43%)]	Loss: 0.792765
# Train Epoch: 47 [25600/45000 (57%)]	Loss: 0.631423
# Train Epoch: 47 [32000/45000 (71%)]	Loss: 0.848123
# Train Epoch: 47 [38400/45000 (85%)]	Loss: 0.911709
# Train Epoch: 47 [44800/45000 (99%)]	Loss: 0.926208
#
# Validation set: Avg. loss: -3.5921, Accuracy: 3642/5000 (73%)
#
# Train Epoch: 48 [0/45000 (0%)]	Loss: 0.646972
# Train Epoch: 48 [6400/45000 (14%)]	Loss: 0.678011
# Train Epoch: 48 [12800/45000 (28%)]	Loss: 0.764088
# Train Epoch: 48 [19200/45000 (43%)]	Loss: 0.671889
# Train Epoch: 48 [25600/45000 (57%)]	Loss: 0.634989
# Train Epoch: 48 [32000/45000 (71%)]	Loss: 0.715096
# Train Epoch: 48 [38400/45000 (85%)]	Loss: 0.729365
# Train Epoch: 48 [44800/45000 (99%)]	Loss: 0.712622
#
# Validation set: Avg. loss: -3.6092, Accuracy: 3625/5000 (72%)
#
# Train Epoch: 49 [0/45000 (0%)]	Loss: 0.557598
# Train Epoch: 49 [6400/45000 (14%)]	Loss: 0.507070
# Train Epoch: 49 [12800/45000 (28%)]	Loss: 0.671449
# Train Epoch: 49 [19200/45000 (43%)]	Loss: 0.549582
# Train Epoch: 49 [25600/45000 (57%)]	Loss: 0.662557
# Train Epoch: 49 [32000/45000 (71%)]	Loss: 0.902662
# Train Epoch: 49 [38400/45000 (85%)]	Loss: 0.712455
# Train Epoch: 49 [44800/45000 (99%)]	Loss: 0.882522
#
# Validation set: Avg. loss: -3.5026, Accuracy: 3644/5000 (73%)
#
# Train Epoch: 50 [0/45000 (0%)]	Loss: 0.630509
# Train Epoch: 50 [6400/45000 (14%)]	Loss: 0.817258
# Train Epoch: 50 [12800/45000 (28%)]	Loss: 0.712160
# Train Epoch: 50 [19200/45000 (43%)]	Loss: 0.594671
# Train Epoch: 50 [25600/45000 (57%)]	Loss: 0.822787
# Train Epoch: 50 [32000/45000 (71%)]	Loss: 0.822646
# Train Epoch: 50 [38400/45000 (85%)]	Loss: 0.878037
# Train Epoch: 50 [44800/45000 (99%)]	Loss: 0.725098
#
# Validation set: Avg. loss: -3.6909, Accuracy: 3757/5000 (75%)
#
# Train Epoch: 51 [0/45000 (0%)]	Loss: 0.633170
# Train Epoch: 51 [6400/45000 (14%)]	Loss: 0.756835
# Train Epoch: 51 [12800/45000 (28%)]	Loss: 0.555232
# Train Epoch: 51 [19200/45000 (43%)]	Loss: 0.633787
# Train Epoch: 51 [25600/45000 (57%)]	Loss: 0.716130
# Train Epoch: 51 [32000/45000 (71%)]	Loss: 0.541559
# Train Epoch: 51 [38400/45000 (85%)]	Loss: 0.591538
# Train Epoch: 51 [44800/45000 (99%)]	Loss: 0.767773
#
# Validation set: Avg. loss: -3.6931, Accuracy: 3742/5000 (75%)
#
# Train Epoch: 52 [0/45000 (0%)]	Loss: 0.600951
# Train Epoch: 52 [6400/45000 (14%)]	Loss: 0.726552
# Train Epoch: 52 [12800/45000 (28%)]	Loss: 0.680462
# Train Epoch: 52 [19200/45000 (43%)]	Loss: 0.778176
# Train Epoch: 52 [25600/45000 (57%)]	Loss: 0.600119
# Train Epoch: 52 [32000/45000 (71%)]	Loss: 0.883792
# Train Epoch: 52 [38400/45000 (85%)]	Loss: 0.739457
# Train Epoch: 52 [44800/45000 (99%)]	Loss: 0.631875
#
# Validation set: Avg. loss: -3.6287, Accuracy: 3676/5000 (74%)
#
# Train Epoch: 53 [0/45000 (0%)]	Loss: 0.520563
# Train Epoch: 53 [6400/45000 (14%)]	Loss: 0.648996
# Train Epoch: 53 [12800/45000 (28%)]	Loss: 0.610387
# Train Epoch: 53 [19200/45000 (43%)]	Loss: 0.662036
# Train Epoch: 53 [25600/45000 (57%)]	Loss: 0.735695
# Train Epoch: 53 [32000/45000 (71%)]	Loss: 0.532938
# Train Epoch: 53 [38400/45000 (85%)]	Loss: 0.711429
# Train Epoch: 53 [44800/45000 (99%)]	Loss: 0.470553
#
# Validation set: Avg. loss: -3.6610, Accuracy: 3697/5000 (74%)
#
# Train Epoch: 54 [0/45000 (0%)]	Loss: 0.708961
# Train Epoch: 54 [6400/45000 (14%)]	Loss: 0.723395
# Train Epoch: 54 [12800/45000 (28%)]	Loss: 0.654337
# Train Epoch: 54 [19200/45000 (43%)]	Loss: 0.571518
# Train Epoch: 54 [25600/45000 (57%)]	Loss: 0.544024
# Train Epoch: 54 [32000/45000 (71%)]	Loss: 0.799784
# Train Epoch: 54 [38400/45000 (85%)]	Loss: 0.504758
# Train Epoch: 54 [44800/45000 (99%)]	Loss: 0.568815
#
# Validation set: Avg. loss: -3.6872, Accuracy: 3715/5000 (74%)
#
# Train Epoch: 55 [0/45000 (0%)]	Loss: 0.804690
# Train Epoch: 55 [6400/45000 (14%)]	Loss: 0.710516
# Train Epoch: 55 [12800/45000 (28%)]	Loss: 0.565094
# Train Epoch: 55 [19200/45000 (43%)]	Loss: 0.843977
# Train Epoch: 55 [25600/45000 (57%)]	Loss: 0.627005
# Train Epoch: 55 [32000/45000 (71%)]	Loss: 0.752836
# Train Epoch: 55 [38400/45000 (85%)]	Loss: 0.750209
# Train Epoch: 55 [44800/45000 (99%)]	Loss: 0.702778
#
# Validation set: Avg. loss: -3.6133, Accuracy: 3743/5000 (75%)
#
# Train Epoch: 56 [0/45000 (0%)]	Loss: 0.786011
# Train Epoch: 56 [6400/45000 (14%)]	Loss: 0.689305
# Train Epoch: 56 [12800/45000 (28%)]	Loss: 0.603876
# Train Epoch: 56 [19200/45000 (43%)]	Loss: 0.637577
# Train Epoch: 56 [25600/45000 (57%)]	Loss: 0.510462
# Train Epoch: 56 [32000/45000 (71%)]	Loss: 0.460437
# Train Epoch: 56 [38400/45000 (85%)]	Loss: 0.744712
# Train Epoch: 56 [44800/45000 (99%)]	Loss: 0.736181
#
# Validation set: Avg. loss: -3.6330, Accuracy: 3737/5000 (75%)
#
# Train Epoch: 57 [0/45000 (0%)]	Loss: 0.458382
# Train Epoch: 57 [6400/45000 (14%)]	Loss: 0.663095
# Train Epoch: 57 [12800/45000 (28%)]	Loss: 0.598016
# Train Epoch: 57 [19200/45000 (43%)]	Loss: 0.650013
# Train Epoch: 57 [25600/45000 (57%)]	Loss: 0.822369
# Train Epoch: 57 [32000/45000 (71%)]	Loss: 0.554404
# Train Epoch: 57 [38400/45000 (85%)]	Loss: 0.784134
# Train Epoch: 57 [44800/45000 (99%)]	Loss: 0.568257
#
# Validation set: Avg. loss: -3.6553, Accuracy: 3703/5000 (74%)
#
# Train Epoch: 58 [0/45000 (0%)]	Loss: 0.477603
# Train Epoch: 58 [6400/45000 (14%)]	Loss: 0.778403
# Train Epoch: 58 [12800/45000 (28%)]	Loss: 0.636172
# Train Epoch: 58 [19200/45000 (43%)]	Loss: 0.744584
# Train Epoch: 58 [25600/45000 (57%)]	Loss: 0.630196
# Train Epoch: 58 [32000/45000 (71%)]	Loss: 0.738726
# Train Epoch: 58 [38400/45000 (85%)]	Loss: 0.721176
# Train Epoch: 58 [44800/45000 (99%)]	Loss: 0.823176
#
# Validation set: Avg. loss: -3.6409, Accuracy: 3742/5000 (75%)
#
# Train Epoch: 59 [0/45000 (0%)]	Loss: 0.689140
# Train Epoch: 59 [6400/45000 (14%)]	Loss: 0.758164
# Train Epoch: 59 [12800/45000 (28%)]	Loss: 0.816880
# Train Epoch: 59 [19200/45000 (43%)]	Loss: 0.688178
# Train Epoch: 59 [25600/45000 (57%)]	Loss: 0.663769
# Train Epoch: 59 [32000/45000 (71%)]	Loss: 0.796012
# Train Epoch: 59 [38400/45000 (85%)]	Loss: 0.817628
# Train Epoch: 59 [44800/45000 (99%)]	Loss: 0.735314
#
# Validation set: Avg. loss: -3.6477, Accuracy: 3690/5000 (74%)
#
# Train Epoch: 60 [0/45000 (0%)]	Loss: 0.663974
# Train Epoch: 60 [6400/45000 (14%)]	Loss: 0.648241
# Train Epoch: 60 [12800/45000 (28%)]	Loss: 0.750472
# Train Epoch: 60 [19200/45000 (43%)]	Loss: 0.542342
# Train Epoch: 60 [25600/45000 (57%)]	Loss: 0.691869
# Train Epoch: 60 [32000/45000 (71%)]	Loss: 0.625568
# Train Epoch: 60 [38400/45000 (85%)]	Loss: 0.669311
# Train Epoch: 60 [44800/45000 (99%)]	Loss: 0.504581
#
# Validation set: Avg. loss: -3.6294, Accuracy: 3682/5000 (74%)
#
# Train Epoch: 61 [0/45000 (0%)]	Loss: 0.764698
# Train Epoch: 61 [6400/45000 (14%)]	Loss: 0.810762
# Train Epoch: 61 [12800/45000 (28%)]	Loss: 0.671412
# Train Epoch: 61 [19200/45000 (43%)]	Loss: 0.766261
# Train Epoch: 61 [25600/45000 (57%)]	Loss: 0.804259
# Train Epoch: 61 [32000/45000 (71%)]	Loss: 0.773845
# Train Epoch: 61 [38400/45000 (85%)]	Loss: 0.748018
# Train Epoch: 61 [44800/45000 (99%)]	Loss: 0.882767
#
# Validation set: Avg. loss: -3.6800, Accuracy: 3734/5000 (75%)
#
# Train Epoch: 62 [0/45000 (0%)]	Loss: 0.815759
# Train Epoch: 62 [6400/45000 (14%)]	Loss: 0.732080
# Train Epoch: 62 [12800/45000 (28%)]	Loss: 0.686332
# Train Epoch: 62 [19200/45000 (43%)]	Loss: 0.717525
# Train Epoch: 62 [25600/45000 (57%)]	Loss: 0.781553
# Train Epoch: 62 [32000/45000 (71%)]	Loss: 0.624411
# Train Epoch: 62 [38400/45000 (85%)]	Loss: 0.792239
# Train Epoch: 62 [44800/45000 (99%)]	Loss: 0.672475
#
# Validation set: Avg. loss: -3.6876, Accuracy: 3741/5000 (75%)
#
# Train Epoch: 63 [0/45000 (0%)]	Loss: 0.529137
# Train Epoch: 63 [6400/45000 (14%)]	Loss: 0.518769
# Train Epoch: 63 [12800/45000 (28%)]	Loss: 0.775833
# Train Epoch: 63 [19200/45000 (43%)]	Loss: 1.045432
# Train Epoch: 63 [25600/45000 (57%)]	Loss: 0.554897
# Train Epoch: 63 [32000/45000 (71%)]	Loss: 0.791595
# Train Epoch: 63 [38400/45000 (85%)]	Loss: 0.591062
# Train Epoch: 63 [44800/45000 (99%)]	Loss: 0.791561
#
# Validation set: Avg. loss: -3.6482, Accuracy: 3717/5000 (74%)
#
# Train Epoch: 64 [0/45000 (0%)]	Loss: 0.795192
# Train Epoch: 64 [6400/45000 (14%)]	Loss: 0.919633
# Train Epoch: 64 [12800/45000 (28%)]	Loss: 0.630612
# Train Epoch: 64 [19200/45000 (43%)]	Loss: 0.670541
# Train Epoch: 64 [25600/45000 (57%)]	Loss: 0.638989
# Train Epoch: 64 [32000/45000 (71%)]	Loss: 0.724599
# Train Epoch: 64 [38400/45000 (85%)]	Loss: 0.758635
# Train Epoch: 64 [44800/45000 (99%)]	Loss: 0.608992
#
# Validation set: Avg. loss: -3.6743, Accuracy: 3669/5000 (73%)
#
# Train Epoch: 65 [0/45000 (0%)]	Loss: 0.674666
# Train Epoch: 65 [6400/45000 (14%)]	Loss: 0.757136
# Train Epoch: 65 [12800/45000 (28%)]	Loss: 0.656292
# Train Epoch: 65 [19200/45000 (43%)]	Loss: 0.852679
# Train Epoch: 65 [25600/45000 (57%)]	Loss: 0.546008
# Train Epoch: 65 [32000/45000 (71%)]	Loss: 0.687509
# Train Epoch: 65 [38400/45000 (85%)]	Loss: 0.683884
# Train Epoch: 65 [44800/45000 (99%)]	Loss: 0.504024
#
# Validation set: Avg. loss: -3.6031, Accuracy: 3762/5000 (75%)
#
# Train Epoch: 66 [0/45000 (0%)]	Loss: 0.804234
# Train Epoch: 66 [6400/45000 (14%)]	Loss: 0.551217
# Train Epoch: 66 [12800/45000 (28%)]	Loss: 0.593712
# Train Epoch: 66 [19200/45000 (43%)]	Loss: 0.556896
# Train Epoch: 66 [25600/45000 (57%)]	Loss: 0.514790
# Train Epoch: 66 [32000/45000 (71%)]	Loss: 0.644816
# Train Epoch: 66 [38400/45000 (85%)]	Loss: 0.790333
# Train Epoch: 66 [44800/45000 (99%)]	Loss: 0.938168
#
# Validation set: Avg. loss: -3.6755, Accuracy: 3720/5000 (74%)
#
# Train Epoch: 67 [0/45000 (0%)]	Loss: 0.655341
# Train Epoch: 67 [6400/45000 (14%)]	Loss: 0.738103
# Train Epoch: 67 [12800/45000 (28%)]	Loss: 0.621587
# Train Epoch: 67 [19200/45000 (43%)]	Loss: 0.706134
# Train Epoch: 67 [25600/45000 (57%)]	Loss: 0.778595
# Train Epoch: 67 [32000/45000 (71%)]	Loss: 0.493515
# Train Epoch: 67 [38400/45000 (85%)]	Loss: 0.500445
# Train Epoch: 67 [44800/45000 (99%)]	Loss: 0.629500
#
# Validation set: Avg. loss: -3.6443, Accuracy: 3715/5000 (74%)
#
# Train Epoch: 68 [0/45000 (0%)]	Loss: 0.727491
# Train Epoch: 68 [6400/45000 (14%)]	Loss: 0.737545
# Train Epoch: 68 [12800/45000 (28%)]	Loss: 0.595322
# Train Epoch: 68 [19200/45000 (43%)]	Loss: 0.565754
# Train Epoch: 68 [25600/45000 (57%)]	Loss: 0.519697
# Train Epoch: 68 [32000/45000 (71%)]	Loss: 0.594241
# Train Epoch: 68 [38400/45000 (85%)]	Loss: 0.754981
# Train Epoch: 68 [44800/45000 (99%)]	Loss: 0.647637
#
# Validation set: Avg. loss: -3.6559, Accuracy: 3724/5000 (74%)
#
# Train Epoch: 69 [0/45000 (0%)]	Loss: 0.819652
# Train Epoch: 69 [6400/45000 (14%)]	Loss: 0.800680
# Train Epoch: 69 [12800/45000 (28%)]	Loss: 0.502713
# Train Epoch: 69 [19200/45000 (43%)]	Loss: 0.702253
# Train Epoch: 69 [25600/45000 (57%)]	Loss: 0.467805
# Train Epoch: 69 [32000/45000 (71%)]	Loss: 0.787600
# Train Epoch: 69 [38400/45000 (85%)]	Loss: 0.475630
# Train Epoch: 69 [44800/45000 (99%)]	Loss: 0.759406
#
# Validation set: Avg. loss: -3.6254, Accuracy: 3703/5000 (74%)
#
# Train Epoch: 70 [0/45000 (0%)]	Loss: 0.545395
# Train Epoch: 70 [6400/45000 (14%)]	Loss: 0.631977
# Train Epoch: 70 [12800/45000 (28%)]	Loss: 0.475504
# Train Epoch: 70 [19200/45000 (43%)]	Loss: 0.597839
# Train Epoch: 70 [25600/45000 (57%)]	Loss: 0.694066
# Train Epoch: 70 [32000/45000 (71%)]	Loss: 0.522842
# Train Epoch: 70 [38400/45000 (85%)]	Loss: 0.761317
# Train Epoch: 70 [44800/45000 (99%)]	Loss: 0.678530
#
# Validation set: Avg. loss: -3.6237, Accuracy: 3697/5000 (74%)
#
# Train Epoch: 71 [0/45000 (0%)]	Loss: 0.472211
# Train Epoch: 71 [6400/45000 (14%)]	Loss: 0.632167
# Train Epoch: 71 [12800/45000 (28%)]	Loss: 0.613927
# Train Epoch: 71 [19200/45000 (43%)]	Loss: 0.728718
# Train Epoch: 71 [25600/45000 (57%)]	Loss: 0.632594
# Train Epoch: 71 [32000/45000 (71%)]	Loss: 0.599113
# Train Epoch: 71 [38400/45000 (85%)]	Loss: 0.767333
# Train Epoch: 71 [44800/45000 (99%)]	Loss: 0.617542
#
# Validation set: Avg. loss: -3.6835, Accuracy: 3759/5000 (75%)
#
# Train Epoch: 72 [0/45000 (0%)]	Loss: 0.597376
# Train Epoch: 72 [6400/45000 (14%)]	Loss: 0.581006
# Train Epoch: 72 [12800/45000 (28%)]	Loss: 0.573258
# Train Epoch: 72 [19200/45000 (43%)]	Loss: 0.640774
# Train Epoch: 72 [25600/45000 (57%)]	Loss: 0.747135
# Train Epoch: 72 [32000/45000 (71%)]	Loss: 0.742267
# Train Epoch: 72 [38400/45000 (85%)]	Loss: 0.686443
# Train Epoch: 72 [44800/45000 (99%)]	Loss: 0.765318
#
# Validation set: Avg. loss: -3.6463, Accuracy: 3720/5000 (74%)
#
# Train Epoch: 73 [0/45000 (0%)]	Loss: 0.848675
# Train Epoch: 73 [6400/45000 (14%)]	Loss: 0.620440
# Train Epoch: 73 [12800/45000 (28%)]	Loss: 0.789459
# Train Epoch: 73 [19200/45000 (43%)]	Loss: 0.633053
# Train Epoch: 73 [25600/45000 (57%)]	Loss: 0.534890
# Train Epoch: 73 [32000/45000 (71%)]	Loss: 0.600400
# Train Epoch: 73 [38400/45000 (85%)]	Loss: 0.604401
# Train Epoch: 73 [44800/45000 (99%)]	Loss: 0.693864
#
# Validation set: Avg. loss: -3.6704, Accuracy: 3740/5000 (75%)
#
# Train Epoch: 74 [0/45000 (0%)]	Loss: 0.553021
# Train Epoch: 74 [6400/45000 (14%)]	Loss: 0.899603
# Train Epoch: 74 [12800/45000 (28%)]	Loss: 0.613115
# Train Epoch: 74 [19200/45000 (43%)]	Loss: 0.726309
# Train Epoch: 74 [25600/45000 (57%)]	Loss: 0.771028
# Train Epoch: 74 [32000/45000 (71%)]	Loss: 0.949653
# Train Epoch: 74 [38400/45000 (85%)]	Loss: 0.602001
# Train Epoch: 74 [44800/45000 (99%)]	Loss: 0.713999
#
# Validation set: Avg. loss: -3.6396, Accuracy: 3734/5000 (75%)
#
# Train Epoch: 75 [0/45000 (0%)]	Loss: 0.710952
# Train Epoch: 75 [6400/45000 (14%)]	Loss: 0.630681
# Train Epoch: 75 [12800/45000 (28%)]	Loss: 1.005944
# Train Epoch: 75 [19200/45000 (43%)]	Loss: 0.508149
# Train Epoch: 75 [25600/45000 (57%)]	Loss: 0.807419
# Train Epoch: 75 [32000/45000 (71%)]	Loss: 0.671186
# Train Epoch: 75 [38400/45000 (85%)]	Loss: 0.722883
# Train Epoch: 75 [44800/45000 (99%)]	Loss: 0.632325
#
# Validation set: Avg. loss: -3.6261, Accuracy: 3717/5000 (74%)
#
# Train Epoch: 76 [0/45000 (0%)]	Loss: 0.516119
# Train Epoch: 76 [6400/45000 (14%)]	Loss: 0.632495
# Train Epoch: 76 [12800/45000 (28%)]	Loss: 0.470265
# Train Epoch: 76 [19200/45000 (43%)]	Loss: 0.772834
# Train Epoch: 76 [25600/45000 (57%)]	Loss: 0.726670
# Train Epoch: 76 [32000/45000 (71%)]	Loss: 0.664562
# Train Epoch: 76 [38400/45000 (85%)]	Loss: 0.786722
# Train Epoch: 76 [44800/45000 (99%)]	Loss: 0.911853
#
# Validation set: Avg. loss: -3.7090, Accuracy: 3738/5000 (75%)
#
# Train Epoch: 77 [0/45000 (0%)]	Loss: 0.703023
# Train Epoch: 77 [6400/45000 (14%)]	Loss: 0.824152
# Train Epoch: 77 [12800/45000 (28%)]	Loss: 0.788431
# Train Epoch: 77 [19200/45000 (43%)]	Loss: 0.724189
# Train Epoch: 77 [25600/45000 (57%)]	Loss: 0.885637
# Train Epoch: 77 [32000/45000 (71%)]	Loss: 0.584652
# Train Epoch: 77 [38400/45000 (85%)]	Loss: 0.884552
# Train Epoch: 77 [44800/45000 (99%)]	Loss: 0.561685
#
# Validation set: Avg. loss: -3.7048, Accuracy: 3748/5000 (75%)
#
# Train Epoch: 78 [0/45000 (0%)]	Loss: 0.743361
# Train Epoch: 78 [6400/45000 (14%)]	Loss: 0.853417
# Train Epoch: 78 [12800/45000 (28%)]	Loss: 0.560483
# Train Epoch: 78 [19200/45000 (43%)]	Loss: 0.613551
# Train Epoch: 78 [25600/45000 (57%)]	Loss: 0.757559
# Train Epoch: 78 [32000/45000 (71%)]	Loss: 0.506063
# Train Epoch: 78 [38400/45000 (85%)]	Loss: 0.826013
# Train Epoch: 78 [44800/45000 (99%)]	Loss: 0.511983
#
# Validation set: Avg. loss: -3.6801, Accuracy: 3773/5000 (75%)
#
# Train Epoch: 79 [0/45000 (0%)]	Loss: 0.558078
# Train Epoch: 79 [6400/45000 (14%)]	Loss: 0.739864
# Train Epoch: 79 [12800/45000 (28%)]	Loss: 0.557568
# Train Epoch: 79 [19200/45000 (43%)]	Loss: 0.627049
# Train Epoch: 79 [25600/45000 (57%)]	Loss: 0.584174
# Train Epoch: 79 [32000/45000 (71%)]	Loss: 0.690706
# Train Epoch: 79 [38400/45000 (85%)]	Loss: 0.568463
# Train Epoch: 79 [44800/45000 (99%)]	Loss: 0.647096
#
# Validation set: Avg. loss: -3.6218, Accuracy: 3722/5000 (74%)
#
# Train Epoch: 80 [0/45000 (0%)]	Loss: 0.700639
# Train Epoch: 80 [6400/45000 (14%)]	Loss: 0.676608
# Train Epoch: 80 [12800/45000 (28%)]	Loss: 0.739383
# Train Epoch: 80 [19200/45000 (43%)]	Loss: 0.498678
# Train Epoch: 80 [25600/45000 (57%)]	Loss: 0.473642
# Train Epoch: 80 [32000/45000 (71%)]	Loss: 0.637699
# Train Epoch: 80 [38400/45000 (85%)]	Loss: 0.813534
# Train Epoch: 80 [44800/45000 (99%)]	Loss: 0.674089
#
# Validation set: Avg. loss: -3.6772, Accuracy: 3772/5000 (75%)
#
# Train Epoch: 81 [0/45000 (0%)]	Loss: 0.779990
# Train Epoch: 81 [6400/45000 (14%)]	Loss: 0.801628
# Train Epoch: 81 [12800/45000 (28%)]	Loss: 0.595044
# Train Epoch: 81 [19200/45000 (43%)]	Loss: 0.617694
# Train Epoch: 81 [25600/45000 (57%)]	Loss: 0.633443
# Train Epoch: 81 [32000/45000 (71%)]	Loss: 0.743866
# Train Epoch: 81 [38400/45000 (85%)]	Loss: 0.807893
# Train Epoch: 81 [44800/45000 (99%)]	Loss: 0.613127
#
# Validation set: Avg. loss: -3.6928, Accuracy: 3772/5000 (75%)
#
# Train Epoch: 82 [0/45000 (0%)]	Loss: 0.636588
# Train Epoch: 82 [6400/45000 (14%)]	Loss: 0.496205
# Train Epoch: 82 [12800/45000 (28%)]	Loss: 0.679792
# Train Epoch: 82 [19200/45000 (43%)]	Loss: 0.578389
# Train Epoch: 82 [25600/45000 (57%)]	Loss: 0.499462
# Train Epoch: 82 [32000/45000 (71%)]	Loss: 0.729461
# Train Epoch: 82 [38400/45000 (85%)]	Loss: 0.717176
# Train Epoch: 82 [44800/45000 (99%)]	Loss: 0.693866
#
# Validation set: Avg. loss: -3.6172, Accuracy: 3693/5000 (74%)
#
# Train Epoch: 83 [0/45000 (0%)]	Loss: 0.840904
# Train Epoch: 83 [6400/45000 (14%)]	Loss: 0.443598
# Train Epoch: 83 [12800/45000 (28%)]	Loss: 0.458960
# Train Epoch: 83 [19200/45000 (43%)]	Loss: 0.641672
# Train Epoch: 83 [25600/45000 (57%)]	Loss: 0.606955
# Train Epoch: 83 [32000/45000 (71%)]	Loss: 0.672066
# Train Epoch: 83 [38400/45000 (85%)]	Loss: 0.676928
# Train Epoch: 83 [44800/45000 (99%)]	Loss: 0.470528
#
# Validation set: Avg. loss: -3.6603, Accuracy: 3729/5000 (75%)
#
# Train Epoch: 84 [0/45000 (0%)]	Loss: 0.727215
# Train Epoch: 84 [6400/45000 (14%)]	Loss: 0.658097
# Train Epoch: 84 [12800/45000 (28%)]	Loss: 0.618277
# Train Epoch: 84 [19200/45000 (43%)]	Loss: 0.737584
# Train Epoch: 84 [25600/45000 (57%)]	Loss: 0.493870
# Train Epoch: 84 [32000/45000 (71%)]	Loss: 0.821895
# Train Epoch: 84 [38400/45000 (85%)]	Loss: 0.617332
# Train Epoch: 84 [44800/45000 (99%)]	Loss: 0.566340
#
# Validation set: Avg. loss: -3.6164, Accuracy: 3721/5000 (74%)
#
# Train Epoch: 85 [0/45000 (0%)]	Loss: 0.801616
# Train Epoch: 85 [6400/45000 (14%)]	Loss: 0.840752
# Train Epoch: 85 [12800/45000 (28%)]	Loss: 0.633586
# Train Epoch: 85 [19200/45000 (43%)]	Loss: 0.897428
# Train Epoch: 85 [25600/45000 (57%)]	Loss: 1.049280
# Train Epoch: 85 [32000/45000 (71%)]	Loss: 0.494786
# Train Epoch: 85 [38400/45000 (85%)]	Loss: 0.654354
# Train Epoch: 85 [44800/45000 (99%)]	Loss: 0.385899
#
# Validation set: Avg. loss: -3.6600, Accuracy: 3722/5000 (74%)
#
# Train Epoch: 86 [0/45000 (0%)]	Loss: 0.489283
# Train Epoch: 86 [6400/45000 (14%)]	Loss: 0.479961
# Train Epoch: 86 [12800/45000 (28%)]	Loss: 0.660148
# Train Epoch: 86 [19200/45000 (43%)]	Loss: 0.732290
# Train Epoch: 86 [25600/45000 (57%)]	Loss: 0.545614
# Train Epoch: 86 [32000/45000 (71%)]	Loss: 0.529714
# Train Epoch: 86 [38400/45000 (85%)]	Loss: 0.495472
# Train Epoch: 86 [44800/45000 (99%)]	Loss: 0.736265
#
# Validation set: Avg. loss: -3.6223, Accuracy: 3743/5000 (75%)
#
# Train Epoch: 87 [0/45000 (0%)]	Loss: 0.569692
# Train Epoch: 87 [6400/45000 (14%)]	Loss: 0.621448
# Train Epoch: 87 [12800/45000 (28%)]	Loss: 0.607352
# Train Epoch: 87 [19200/45000 (43%)]	Loss: 0.500273
# Train Epoch: 87 [25600/45000 (57%)]	Loss: 0.541266
# Train Epoch: 87 [32000/45000 (71%)]	Loss: 0.513103
# Train Epoch: 87 [38400/45000 (85%)]	Loss: 0.823146
# Train Epoch: 87 [44800/45000 (99%)]	Loss: 0.782803
#
# Validation set: Avg. loss: -3.5864, Accuracy: 3793/5000 (76%)
#
# Train Epoch: 88 [0/45000 (0%)]	Loss: 0.774797
# Train Epoch: 88 [6400/45000 (14%)]	Loss: 0.636379
# Train Epoch: 88 [12800/45000 (28%)]	Loss: 0.756572
# Train Epoch: 88 [19200/45000 (43%)]	Loss: 0.675383
# Train Epoch: 88 [25600/45000 (57%)]	Loss: 0.597536
# Train Epoch: 88 [32000/45000 (71%)]	Loss: 0.724076
# Train Epoch: 88 [38400/45000 (85%)]	Loss: 0.502595
# Train Epoch: 88 [44800/45000 (99%)]	Loss: 0.839123
#
# Validation set: Avg. loss: -3.6256, Accuracy: 3775/5000 (76%)
#
# Train Epoch: 89 [0/45000 (0%)]	Loss: 0.739279
# Train Epoch: 89 [6400/45000 (14%)]	Loss: 0.659938
# Train Epoch: 89 [12800/45000 (28%)]	Loss: 0.469023
# Train Epoch: 89 [19200/45000 (43%)]	Loss: 0.705082
# Train Epoch: 89 [25600/45000 (57%)]	Loss: 0.593056
# Train Epoch: 89 [32000/45000 (71%)]	Loss: 0.590770
# Train Epoch: 89 [38400/45000 (85%)]	Loss: 0.627882
# Train Epoch: 89 [44800/45000 (99%)]	Loss: 0.615540
#
# Validation set: Avg. loss: -3.6485, Accuracy: 3741/5000 (75%)
#
# Train Epoch: 90 [0/45000 (0%)]	Loss: 0.762910
# Train Epoch: 90 [6400/45000 (14%)]	Loss: 0.723005
# Train Epoch: 90 [12800/45000 (28%)]	Loss: 0.625249
# Train Epoch: 90 [19200/45000 (43%)]	Loss: 0.403705
# Train Epoch: 90 [25600/45000 (57%)]	Loss: 0.686723
# Train Epoch: 90 [32000/45000 (71%)]	Loss: 0.603360
# Train Epoch: 90 [38400/45000 (85%)]	Loss: 0.705709
# Train Epoch: 90 [44800/45000 (99%)]	Loss: 0.733538
#
# Validation set: Avg. loss: -3.6245, Accuracy: 3729/5000 (75%)
#
# Train Epoch: 91 [0/45000 (0%)]	Loss: 0.591851
# Train Epoch: 91 [6400/45000 (14%)]	Loss: 0.662878
# Train Epoch: 91 [12800/45000 (28%)]	Loss: 0.806448
# Train Epoch: 91 [19200/45000 (43%)]	Loss: 0.891307
# Train Epoch: 91 [25600/45000 (57%)]	Loss: 0.508457
# Train Epoch: 91 [32000/45000 (71%)]	Loss: 0.820247
# Train Epoch: 91 [38400/45000 (85%)]	Loss: 0.746022
# Train Epoch: 91 [44800/45000 (99%)]	Loss: 0.714740
#
# Validation set: Avg. loss: -3.6501, Accuracy: 3785/5000 (76%)
#
# Train Epoch: 92 [0/45000 (0%)]	Loss: 0.488688
# Train Epoch: 92 [6400/45000 (14%)]	Loss: 0.700113
# Train Epoch: 92 [12800/45000 (28%)]	Loss: 0.563488
# Train Epoch: 92 [19200/45000 (43%)]	Loss: 0.748340
# Train Epoch: 92 [25600/45000 (57%)]	Loss: 0.756044
# Train Epoch: 92 [32000/45000 (71%)]	Loss: 0.880161
# Train Epoch: 92 [38400/45000 (85%)]	Loss: 0.614869
# Train Epoch: 92 [44800/45000 (99%)]	Loss: 0.551590
#
# Validation set: Avg. loss: -3.6507, Accuracy: 3764/5000 (75%)
#
# Train Epoch: 93 [0/45000 (0%)]	Loss: 0.751379
# Train Epoch: 93 [6400/45000 (14%)]	Loss: 0.471210
# Train Epoch: 93 [12800/45000 (28%)]	Loss: 0.815245
# Train Epoch: 93 [19200/45000 (43%)]	Loss: 0.831564
# Train Epoch: 93 [25600/45000 (57%)]	Loss: 0.683029
# Train Epoch: 93 [32000/45000 (71%)]	Loss: 0.710218
# Train Epoch: 93 [38400/45000 (85%)]	Loss: 0.841348
# Train Epoch: 93 [44800/45000 (99%)]	Loss: 0.813329
#
# Validation set: Avg. loss: -3.6368, Accuracy: 3763/5000 (75%)
#
# Train Epoch: 94 [0/45000 (0%)]	Loss: 0.532901
# Train Epoch: 94 [6400/45000 (14%)]	Loss: 0.822943
# Train Epoch: 94 [12800/45000 (28%)]	Loss: 0.703850
# Train Epoch: 94 [19200/45000 (43%)]	Loss: 0.579039
# Train Epoch: 94 [25600/45000 (57%)]	Loss: 0.711254
# Train Epoch: 94 [32000/45000 (71%)]	Loss: 0.932213
# Train Epoch: 94 [38400/45000 (85%)]	Loss: 0.466679
# Train Epoch: 94 [44800/45000 (99%)]	Loss: 0.565413
#
# Validation set: Avg. loss: -3.6403, Accuracy: 3771/5000 (75%)
#
# Train Epoch: 95 [0/45000 (0%)]	Loss: 0.665403
# Train Epoch: 95 [6400/45000 (14%)]	Loss: 0.773542
# Train Epoch: 95 [12800/45000 (28%)]	Loss: 0.759192
# Train Epoch: 95 [19200/45000 (43%)]	Loss: 0.737389
# Train Epoch: 95 [25600/45000 (57%)]	Loss: 0.663378
# Train Epoch: 95 [32000/45000 (71%)]	Loss: 0.522377
# Train Epoch: 95 [38400/45000 (85%)]	Loss: 0.806398
# Train Epoch: 95 [44800/45000 (99%)]	Loss: 0.681203
#
# Validation set: Avg. loss: -3.6076, Accuracy: 3762/5000 (75%)
#
# Train Epoch: 96 [0/45000 (0%)]	Loss: 0.676667
# Train Epoch: 96 [6400/45000 (14%)]	Loss: 0.543047
# Train Epoch: 96 [12800/45000 (28%)]	Loss: 0.506744
# Train Epoch: 96 [19200/45000 (43%)]	Loss: 0.719758
# Train Epoch: 96 [25600/45000 (57%)]	Loss: 0.529429
# Train Epoch: 96 [32000/45000 (71%)]	Loss: 0.493118
# Train Epoch: 96 [38400/45000 (85%)]	Loss: 0.884199
# Train Epoch: 96 [44800/45000 (99%)]	Loss: 0.722169
#
# Validation set: Avg. loss: -3.6961, Accuracy: 3791/5000 (76%)
#
# Train Epoch: 97 [0/45000 (0%)]	Loss: 0.550291
# Train Epoch: 97 [6400/45000 (14%)]	Loss: 0.628541
# Train Epoch: 97 [12800/45000 (28%)]	Loss: 0.539423
# Train Epoch: 97 [19200/45000 (43%)]	Loss: 0.471207
# Train Epoch: 97 [25600/45000 (57%)]	Loss: 0.560904
# Train Epoch: 97 [32000/45000 (71%)]	Loss: 0.644750
# Train Epoch: 97 [38400/45000 (85%)]	Loss: 0.552623
# Train Epoch: 97 [44800/45000 (99%)]	Loss: 0.527251
#
# Validation set: Avg. loss: -3.7067, Accuracy: 3760/5000 (75%)
#
# Train Epoch: 98 [0/45000 (0%)]	Loss: 0.461580
# Train Epoch: 98 [6400/45000 (14%)]	Loss: 0.742983
# Train Epoch: 98 [12800/45000 (28%)]	Loss: 0.595964
# Train Epoch: 98 [19200/45000 (43%)]	Loss: 0.649151
# Train Epoch: 98 [25600/45000 (57%)]	Loss: 0.620520
# Train Epoch: 98 [32000/45000 (71%)]	Loss: 0.609540
# Train Epoch: 98 [38400/45000 (85%)]	Loss: 0.655248
# Train Epoch: 98 [44800/45000 (99%)]	Loss: 0.553072
#
# Validation set: Avg. loss: -3.7002, Accuracy: 3766/5000 (75%)
#
# Train Epoch: 99 [0/45000 (0%)]	Loss: 0.752287
# Train Epoch: 99 [6400/45000 (14%)]	Loss: 0.574647
# Train Epoch: 99 [12800/45000 (28%)]	Loss: 0.586528
# Train Epoch: 99 [19200/45000 (43%)]	Loss: 0.834644
# Train Epoch: 99 [25600/45000 (57%)]	Loss: 0.708209
# Train Epoch: 99 [32000/45000 (71%)]	Loss: 0.748321
# Train Epoch: 99 [38400/45000 (85%)]	Loss: 0.862108
# Train Epoch: 99 [44800/45000 (99%)]	Loss: 0.804340
#
# Validation set: Avg. loss: -3.6052, Accuracy: 3766/5000 (75%)
#
# Train Epoch: 100 [0/45000 (0%)]	Loss: 0.499064
# Train Epoch: 100 [6400/45000 (14%)]	Loss: 0.616131
# Train Epoch: 100 [12800/45000 (28%)]	Loss: 0.585270
# Train Epoch: 100 [19200/45000 (43%)]	Loss: 0.647326
# Train Epoch: 100 [25600/45000 (57%)]	Loss: 0.576513
# Train Epoch: 100 [32000/45000 (71%)]	Loss: 0.744606
# Train Epoch: 100 [38400/45000 (85%)]	Loss: 0.605278
# Train Epoch: 100 [44800/45000 (99%)]	Loss: 0.635901
#
# Validation set: Avg. loss: -3.6940, Accuracy: 3774/5000 (75%)
#
# Train Epoch: 101 [0/45000 (0%)]	Loss: 0.706964
# Train Epoch: 101 [6400/45000 (14%)]	Loss: 0.597279
# Train Epoch: 101 [12800/45000 (28%)]	Loss: 0.650984
# Train Epoch: 101 [19200/45000 (43%)]	Loss: 0.523692
# Train Epoch: 101 [25600/45000 (57%)]	Loss: 0.583716
# Train Epoch: 101 [32000/45000 (71%)]	Loss: 0.438509
# Train Epoch: 101 [38400/45000 (85%)]	Loss: 0.506220
# Train Epoch: 101 [44800/45000 (99%)]	Loss: 0.446276
#
# Validation set: Avg. loss: -3.7568, Accuracy: 3781/5000 (76%)
#
# Train Epoch: 102 [0/45000 (0%)]	Loss: 0.948928
# Train Epoch: 102 [6400/45000 (14%)]	Loss: 0.596328
# Train Epoch: 102 [12800/45000 (28%)]	Loss: 0.784005
# Train Epoch: 102 [19200/45000 (43%)]	Loss: 0.559907
# Train Epoch: 102 [25600/45000 (57%)]	Loss: 0.758453
# ...
# Train Epoch: 166 [44800/45000 (99%)]	Loss: 0.628052
#
# Validation set: Avg. loss: -3.6945, Accuracy: 3833/5000 (77%)
#
# Train Epoch: 167 [0/45000 (0%)]	Loss: 0.353732
# Train Epoch: 167 [6400/45000 (14%)]	Loss: 0.653457
# Train Epoch: 167 [12800/45000 (28%)]	Loss: 0.601636
# Train Epoch: 167 [19200/45000 (43%)]	Loss: 0.419989
# Train Epoch: 167 [25600/45000 (57%)]	Loss: 0.291215
# Train Epoch: 167 [32000/45000 (71%)]	Loss: 0.655469
# Train Epoch: 167 [38400/45000 (85%)]	Loss: 0.642497
# Train Epoch: 167 [44800/45000 (99%)]	Loss: 0.637262
#
# Validation set: Avg. loss: -3.6798, Accuracy: 3830/5000 (77%)
#
# Train Epoch: 168 [0/45000 (0%)]	Loss: 0.520026
# Train Epoch: 168 [6400/45000 (14%)]	Loss: 0.744661
# Train Epoch: 168 [12800/45000 (28%)]	Loss: 0.590790
# Train Epoch: 168 [19200/45000 (43%)]	Loss: 0.446705
# Train Epoch: 168 [25600/45000 (57%)]	Loss: 0.442555
# Train Epoch: 168 [32000/45000 (71%)]	Loss: 0.659157
# Train Epoch: 168 [38400/45000 (85%)]	Loss: 0.597174
# Train Epoch: 168 [44800/45000 (99%)]	Loss: 0.662240
#
# Validation set: Avg. loss: -3.7725, Accuracy: 3844/5000 (77%)
#
# Train Epoch: 169 [0/45000 (0%)]	Loss: 0.794730
# Train Epoch: 169 [6400/45000 (14%)]	Loss: 0.454417
# Train Epoch: 169 [12800/45000 (28%)]	Loss: 0.757646
# Train Epoch: 169 [19200/45000 (43%)]	Loss: 0.594112
# Train Epoch: 169 [25600/45000 (57%)]	Loss: 0.473952
# Train Epoch: 169 [32000/45000 (71%)]	Loss: 0.617283
# Train Epoch: 169 [38400/45000 (85%)]	Loss: 0.600373
# Train Epoch: 169 [44800/45000 (99%)]	Loss: 0.710369
#
# Validation set: Avg. loss: -3.7416, Accuracy: 3816/5000 (76%)
#
# Train Epoch: 170 [0/45000 (0%)]	Loss: 0.809062
# Train Epoch: 170 [6400/45000 (14%)]	Loss: 0.809339
# Train Epoch: 170 [12800/45000 (28%)]	Loss: 0.714758
# Train Epoch: 170 [19200/45000 (43%)]	Loss: 0.398989
# Train Epoch: 170 [25600/45000 (57%)]	Loss: 0.789345
# Train Epoch: 170 [32000/45000 (71%)]	Loss: 0.483698
# Train Epoch: 170 [38400/45000 (85%)]	Loss: 0.423989
# Train Epoch: 170 [44800/45000 (99%)]	Loss: 0.762221
#
# Validation set: Avg. loss: -3.7218, Accuracy: 3835/5000 (77%)
#
# Train Epoch: 171 [0/45000 (0%)]	Loss: 0.589674
# Train Epoch: 171 [6400/45000 (14%)]	Loss: 0.644769
# Train Epoch: 171 [12800/45000 (28%)]	Loss: 0.686979
# Train Epoch: 171 [19200/45000 (43%)]	Loss: 0.490333
# Train Epoch: 171 [25600/45000 (57%)]	Loss: 0.862094
# Train Epoch: 171 [32000/45000 (71%)]	Loss: 0.584734
# Train Epoch: 171 [38400/45000 (85%)]	Loss: 0.540438
# Train Epoch: 171 [44800/45000 (99%)]	Loss: 0.597053
#
# Validation set: Avg. loss: -3.7352, Accuracy: 3843/5000 (77%)
#
# Train Epoch: 172 [0/45000 (0%)]	Loss: 0.512899
# Train Epoch: 172 [6400/45000 (14%)]	Loss: 0.733208
# Train Epoch: 172 [12800/45000 (28%)]	Loss: 0.512933
# Train Epoch: 172 [19200/45000 (43%)]	Loss: 0.510972
# Train Epoch: 172 [25600/45000 (57%)]	Loss: 0.562714
# Train Epoch: 172 [32000/45000 (71%)]	Loss: 0.553796
# Train Epoch: 172 [38400/45000 (85%)]	Loss: 0.954312
# Train Epoch: 172 [44800/45000 (99%)]	Loss: 0.688028
#
# Validation set: Avg. loss: -3.6750, Accuracy: 3819/5000 (76%)
#
# Train Epoch: 173 [0/45000 (0%)]	Loss: 0.480080
# Train Epoch: 173 [6400/45000 (14%)]	Loss: 0.546191
# Train Epoch: 173 [12800/45000 (28%)]	Loss: 0.564009
# Train Epoch: 173 [19200/45000 (43%)]	Loss: 0.625555
# Train Epoch: 173 [25600/45000 (57%)]	Loss: 0.390362
# Train Epoch: 173 [32000/45000 (71%)]	Loss: 0.522615
# Train Epoch: 173 [38400/45000 (85%)]	Loss: 0.574495
# Train Epoch: 173 [44800/45000 (99%)]	Loss: 0.596157
#
# Validation set: Avg. loss: -3.7558, Accuracy: 3797/5000 (76%)
#
# Train Epoch: 174 [0/45000 (0%)]	Loss: 0.556679
# Train Epoch: 174 [6400/45000 (14%)]	Loss: 0.499517
# Train Epoch: 174 [12800/45000 (28%)]	Loss: 0.555193
# Train Epoch: 174 [19200/45000 (43%)]	Loss: 0.501330
# Train Epoch: 174 [25600/45000 (57%)]	Loss: 0.523397
# Train Epoch: 174 [32000/45000 (71%)]	Loss: 0.502983
# Train Epoch: 174 [38400/45000 (85%)]	Loss: 0.795442
# Train Epoch: 174 [44800/45000 (99%)]	Loss: 0.585247
#
# Validation set: Avg. loss: -3.7018, Accuracy: 3843/5000 (77%)
#
# Train Epoch: 175 [0/45000 (0%)]	Loss: 0.534824
# Train Epoch: 175 [6400/45000 (14%)]	Loss: 0.493062
# Train Epoch: 175 [12800/45000 (28%)]	Loss: 0.355970
# Train Epoch: 175 [19200/45000 (43%)]	Loss: 0.809522
# Train Epoch: 175 [25600/45000 (57%)]	Loss: 0.599953
# Train Epoch: 175 [32000/45000 (71%)]	Loss: 0.557240
# Train Epoch: 175 [38400/45000 (85%)]	Loss: 0.475368
# Train Epoch: 175 [44800/45000 (99%)]	Loss: 0.464446
#
# Validation set: Avg. loss: -3.7288, Accuracy: 3810/5000 (76%)
#
# Train Epoch: 176 [0/45000 (0%)]	Loss: 0.374990
# Train Epoch: 176 [6400/45000 (14%)]	Loss: 0.524032
# Train Epoch: 176 [12800/45000 (28%)]	Loss: 0.689103
# Train Epoch: 176 [19200/45000 (43%)]	Loss: 0.560743
# Train Epoch: 176 [25600/45000 (57%)]	Loss: 0.541012
# Train Epoch: 176 [32000/45000 (71%)]	Loss: 0.509544
# Train Epoch: 176 [38400/45000 (85%)]	Loss: 0.668180
# Train Epoch: 176 [44800/45000 (99%)]	Loss: 0.623166
#
# Validation set: Avg. loss: -3.7096, Accuracy: 3796/5000 (76%)
#
# Train Epoch: 177 [0/45000 (0%)]	Loss: 0.826655
# Train Epoch: 177 [6400/45000 (14%)]	Loss: 0.660621
# Train Epoch: 177 [12800/45000 (28%)]	Loss: 0.484686
# Train Epoch: 177 [19200/45000 (43%)]	Loss: 0.851635
# Train Epoch: 177 [25600/45000 (57%)]	Loss: 0.658788
# Train Epoch: 177 [32000/45000 (71%)]	Loss: 0.407798
# Train Epoch: 177 [38400/45000 (85%)]	Loss: 0.483647
# Train Epoch: 177 [44800/45000 (99%)]	Loss: 0.568267
#
# Validation set: Avg. loss: -3.7057, Accuracy: 3782/5000 (76%)
#
# Train Epoch: 178 [0/45000 (0%)]	Loss: 0.573872
# Train Epoch: 178 [6400/45000 (14%)]	Loss: 0.445499
# Train Epoch: 178 [12800/45000 (28%)]	Loss: 0.510988
# Train Epoch: 178 [19200/45000 (43%)]	Loss: 0.503724
# Train Epoch: 178 [25600/45000 (57%)]	Loss: 0.501519
# Train Epoch: 178 [32000/45000 (71%)]	Loss: 0.523148
# Train Epoch: 178 [38400/45000 (85%)]	Loss: 0.486352
# Train Epoch: 178 [44800/45000 (99%)]	Loss: 0.386802
#
# Validation set: Avg. loss: -3.6784, Accuracy: 3802/5000 (76%)
#
# Train Epoch: 179 [0/45000 (0%)]	Loss: 0.350267
# Train Epoch: 179 [6400/45000 (14%)]	Loss: 0.528210
# Train Epoch: 179 [12800/45000 (28%)]	Loss: 0.702604
# Train Epoch: 179 [19200/45000 (43%)]	Loss: 0.471924
# Train Epoch: 179 [25600/45000 (57%)]	Loss: 0.621686
# Train Epoch: 179 [32000/45000 (71%)]	Loss: 0.608648
# Train Epoch: 179 [38400/45000 (85%)]	Loss: 0.645823
# Train Epoch: 179 [44800/45000 (99%)]	Loss: 0.569876
#
# Validation set: Avg. loss: -3.7159, Accuracy: 3787/5000 (76%)
#
# Train Epoch: 180 [0/45000 (0%)]	Loss: 0.580988
# Train Epoch: 180 [6400/45000 (14%)]	Loss: 0.601786
# Train Epoch: 180 [12800/45000 (28%)]	Loss: 0.397642
# Train Epoch: 180 [19200/45000 (43%)]	Loss: 0.597365
# Train Epoch: 180 [25600/45000 (57%)]	Loss: 0.681062
# Train Epoch: 180 [32000/45000 (71%)]	Loss: 0.561588
# Train Epoch: 180 [38400/45000 (85%)]	Loss: 0.638261
# Train Epoch: 180 [44800/45000 (99%)]	Loss: 0.790526
#
# Validation set: Avg. loss: -3.6807, Accuracy: 3837/5000 (77%)
#
# Train Epoch: 181 [0/45000 (0%)]	Loss: 0.693753
# Train Epoch: 181 [6400/45000 (14%)]	Loss: 0.527519
# Train Epoch: 181 [12800/45000 (28%)]	Loss: 0.574758
# Train Epoch: 181 [19200/45000 (43%)]	Loss: 0.701974
# Train Epoch: 181 [25600/45000 (57%)]	Loss: 0.428011
# Train Epoch: 181 [32000/45000 (71%)]	Loss: 0.627538
# Train Epoch: 181 [38400/45000 (85%)]	Loss: 0.596617
# Train Epoch: 181 [44800/45000 (99%)]	Loss: 0.639248
#
# Validation set: Avg. loss: -3.7197, Accuracy: 3841/5000 (77%)
#
# Train Epoch: 182 [0/45000 (0%)]	Loss: 0.669769
# Train Epoch: 182 [6400/45000 (14%)]	Loss: 0.398384
# Train Epoch: 182 [12800/45000 (28%)]	Loss: 0.544462
# Train Epoch: 182 [19200/45000 (43%)]	Loss: 0.393477
# Train Epoch: 182 [25600/45000 (57%)]	Loss: 0.376921
# Train Epoch: 182 [32000/45000 (71%)]	Loss: 0.555998
# Train Epoch: 182 [38400/45000 (85%)]	Loss: 0.510988
# Train Epoch: 182 [44800/45000 (99%)]	Loss: 0.482995
#
# Validation set: Avg. loss: -3.7020, Accuracy: 3791/5000 (76%)
#
# Train Epoch: 183 [0/45000 (0%)]	Loss: 0.489760
# Train Epoch: 183 [6400/45000 (14%)]	Loss: 0.599004
# Train Epoch: 183 [12800/45000 (28%)]	Loss: 0.553937
# Train Epoch: 183 [19200/45000 (43%)]	Loss: 0.661500
# Train Epoch: 183 [25600/45000 (57%)]	Loss: 0.556281
# Train Epoch: 183 [32000/45000 (71%)]	Loss: 0.522241
# Train Epoch: 183 [38400/45000 (85%)]	Loss: 0.521583
# Train Epoch: 183 [44800/45000 (99%)]	Loss: 0.776894
#
# Validation set: Avg. loss: -3.7036, Accuracy: 3837/5000 (77%)
#
# Train Epoch: 184 [0/45000 (0%)]	Loss: 0.595078
# Train Epoch: 184 [6400/45000 (14%)]	Loss: 0.621489
# Train Epoch: 184 [12800/45000 (28%)]	Loss: 0.559520
# Train Epoch: 184 [19200/45000 (43%)]	Loss: 0.674219
# Train Epoch: 184 [25600/45000 (57%)]	Loss: 0.337296
# Train Epoch: 184 [32000/45000 (71%)]	Loss: 0.588915
# Train Epoch: 184 [38400/45000 (85%)]	Loss: 0.639660
# Train Epoch: 184 [44800/45000 (99%)]	Loss: 0.518361
#
# Validation set: Avg. loss: -3.7269, Accuracy: 3825/5000 (76%)
#
# Train Epoch: 185 [0/45000 (0%)]	Loss: 0.634275
# Train Epoch: 185 [6400/45000 (14%)]	Loss: 0.711627
# Train Epoch: 185 [12800/45000 (28%)]	Loss: 0.472877
# Train Epoch: 185 [19200/45000 (43%)]	Loss: 0.555200
# Train Epoch: 185 [25600/45000 (57%)]	Loss: 0.770630
# Train Epoch: 185 [32000/45000 (71%)]	Loss: 0.549949
# Train Epoch: 185 [38400/45000 (85%)]	Loss: 0.506389
# Train Epoch: 185 [44800/45000 (99%)]	Loss: 0.673800
#
# Validation set: Avg. loss: -3.7185, Accuracy: 3830/5000 (77%)
#
# Train Epoch: 186 [0/45000 (0%)]	Loss: 0.429668
# Train Epoch: 186 [6400/45000 (14%)]	Loss: 0.560551
# Train Epoch: 186 [12800/45000 (28%)]	Loss: 0.549232
# Train Epoch: 186 [19200/45000 (43%)]	Loss: 0.605267
# Train Epoch: 186 [25600/45000 (57%)]	Loss: 0.620776
# Train Epoch: 186 [32000/45000 (71%)]	Loss: 0.508552
# Train Epoch: 186 [38400/45000 (85%)]	Loss: 0.551907
# Train Epoch: 186 [44800/45000 (99%)]	Loss: 0.426232
#
# Validation set: Avg. loss: -3.7259, Accuracy: 3859/5000 (77%)
#
# Train Epoch: 187 [0/45000 (0%)]	Loss: 0.756810
# Train Epoch: 187 [6400/45000 (14%)]	Loss: 0.646494
# Train Epoch: 187 [12800/45000 (28%)]	Loss: 0.384966
# Train Epoch: 187 [19200/45000 (43%)]	Loss: 0.488444
# Train Epoch: 187 [25600/45000 (57%)]	Loss: 0.712903
# Train Epoch: 187 [32000/45000 (71%)]	Loss: 0.637580
# Train Epoch: 187 [38400/45000 (85%)]	Loss: 0.517977
# Train Epoch: 187 [44800/45000 (99%)]	Loss: 0.758880
#
# Validation set: Avg. loss: -3.7288, Accuracy: 3817/5000 (76%)
#
# Train Epoch: 188 [0/45000 (0%)]	Loss: 0.484771
# Train Epoch: 188 [6400/45000 (14%)]	Loss: 0.806212
# Train Epoch: 188 [12800/45000 (28%)]	Loss: 0.554335
# Train Epoch: 188 [19200/45000 (43%)]	Loss: 0.605663
# Train Epoch: 188 [25600/45000 (57%)]	Loss: 0.829593
# Train Epoch: 188 [32000/45000 (71%)]	Loss: 0.585568
# Train Epoch: 188 [38400/45000 (85%)]	Loss: 0.499865
# Train Epoch: 188 [44800/45000 (99%)]	Loss: 0.504927
#
# Validation set: Avg. loss: -3.7923, Accuracy: 3816/5000 (76%)
#
# Train Epoch: 189 [0/45000 (0%)]	Loss: 0.632791
# Train Epoch: 189 [6400/45000 (14%)]	Loss: 0.448328
# Train Epoch: 189 [12800/45000 (28%)]	Loss: 0.536764
# Train Epoch: 189 [19200/45000 (43%)]	Loss: 0.487619
# Train Epoch: 189 [25600/45000 (57%)]	Loss: 0.802889
# Train Epoch: 189 [32000/45000 (71%)]	Loss: 0.545665
# Train Epoch: 189 [38400/45000 (85%)]	Loss: 0.591968
# Train Epoch: 189 [44800/45000 (99%)]	Loss: 0.716334
#
# Validation set: Avg. loss: -3.7618, Accuracy: 3832/5000 (77%)
#
# Train Epoch: 190 [0/45000 (0%)]	Loss: 0.455405
# Train Epoch: 190 [6400/45000 (14%)]	Loss: 0.464370
# Train Epoch: 190 [12800/45000 (28%)]	Loss: 0.539947
# Train Epoch: 190 [19200/45000 (43%)]	Loss: 0.502907
# Train Epoch: 190 [25600/45000 (57%)]	Loss: 0.736050
# Train Epoch: 190 [32000/45000 (71%)]	Loss: 0.494316
# Train Epoch: 190 [38400/45000 (85%)]	Loss: 0.745793
# Train Epoch: 190 [44800/45000 (99%)]	Loss: 0.632234
#
# Validation set: Avg. loss: -3.7860, Accuracy: 3805/5000 (76%)
#
# Train Epoch: 191 [0/45000 (0%)]	Loss: 0.538389
# Train Epoch: 191 [6400/45000 (14%)]	Loss: 0.743414
# Train Epoch: 191 [12800/45000 (28%)]	Loss: 0.538648
# Train Epoch: 191 [19200/45000 (43%)]	Loss: 0.701036
# Train Epoch: 191 [25600/45000 (57%)]	Loss: 0.674757
# Train Epoch: 191 [32000/45000 (71%)]	Loss: 0.319691
# Train Epoch: 191 [38400/45000 (85%)]	Loss: 0.482899
# Train Epoch: 191 [44800/45000 (99%)]	Loss: 0.485880
#
# Validation set: Avg. loss: -3.7874, Accuracy: 3837/5000 (77%)
#
# Train Epoch: 192 [0/45000 (0%)]	Loss: 0.497391
# Train Epoch: 192 [6400/45000 (14%)]	Loss: 0.530870
# Train Epoch: 192 [12800/45000 (28%)]	Loss: 0.528162
# Train Epoch: 192 [19200/45000 (43%)]	Loss: 0.508050
# Train Epoch: 192 [25600/45000 (57%)]	Loss: 0.478430
# Train Epoch: 192 [32000/45000 (71%)]	Loss: 0.512512
# Train Epoch: 192 [38400/45000 (85%)]	Loss: 0.497130
# Train Epoch: 192 [44800/45000 (99%)]	Loss: 0.401806
#
# Validation set: Avg. loss: -3.7745, Accuracy: 3831/5000 (77%)
#
# Train Epoch: 193 [0/45000 (0%)]	Loss: 0.522720
# Train Epoch: 193 [6400/45000 (14%)]	Loss: 0.610809
# Train Epoch: 193 [12800/45000 (28%)]	Loss: 0.634304
# Train Epoch: 193 [19200/45000 (43%)]	Loss: 0.703320
# Train Epoch: 193 [25600/45000 (57%)]	Loss: 0.477881
# Train Epoch: 193 [32000/45000 (71%)]	Loss: 0.493069
# Train Epoch: 193 [38400/45000 (85%)]	Loss: 0.619488
# Train Epoch: 193 [44800/45000 (99%)]	Loss: 0.599896
#
# Validation set: Avg. loss: -3.7584, Accuracy: 3838/5000 (77%)
#
# Train Epoch: 194 [0/45000 (0%)]	Loss: 0.402602
# Train Epoch: 194 [6400/45000 (14%)]	Loss: 0.542649
# Train Epoch: 194 [12800/45000 (28%)]	Loss: 0.598480
# Train Epoch: 194 [19200/45000 (43%)]	Loss: 0.486869
# Train Epoch: 194 [25600/45000 (57%)]	Loss: 0.648306
# Train Epoch: 194 [32000/45000 (71%)]	Loss: 0.634302
# Train Epoch: 194 [38400/45000 (85%)]	Loss: 0.592544
# Train Epoch: 194 [44800/45000 (99%)]	Loss: 0.437372
#
# Validation set: Avg. loss: -3.8062, Accuracy: 3829/5000 (77%)
#
# Train Epoch: 195 [0/45000 (0%)]	Loss: 0.494541
# Train Epoch: 195 [6400/45000 (14%)]	Loss: 0.648661
# Train Epoch: 195 [12800/45000 (28%)]	Loss: 0.384087
# Train Epoch: 195 [19200/45000 (43%)]	Loss: 0.611923
# Train Epoch: 195 [25600/45000 (57%)]	Loss: 0.566936
# Train Epoch: 195 [32000/45000 (71%)]	Loss: 0.407857
# Train Epoch: 195 [38400/45000 (85%)]	Loss: 0.443444
# Train Epoch: 195 [44800/45000 (99%)]	Loss: 0.407512
#
# Validation set: Avg. loss: -3.7058, Accuracy: 3818/5000 (76%)
#
# Train Epoch: 196 [0/45000 (0%)]	Loss: 0.530769
# Train Epoch: 196 [6400/45000 (14%)]	Loss: 0.557550
# Train Epoch: 196 [12800/45000 (28%)]	Loss: 0.539098
# Train Epoch: 196 [19200/45000 (43%)]	Loss: 0.417850
# Train Epoch: 196 [25600/45000 (57%)]	Loss: 0.473432
# Train Epoch: 196 [32000/45000 (71%)]	Loss: 0.773305
# Train Epoch: 196 [38400/45000 (85%)]	Loss: 0.434251
# Train Epoch: 196 [44800/45000 (99%)]	Loss: 0.540356
#
# Validation set: Avg. loss: -3.7772, Accuracy: 3849/5000 (77%)
#
# Train Epoch: 197 [0/45000 (0%)]	Loss: 0.560980
# Train Epoch: 197 [6400/45000 (14%)]	Loss: 0.850864
# Train Epoch: 197 [12800/45000 (28%)]	Loss: 0.651702
# Train Epoch: 197 [19200/45000 (43%)]	Loss: 0.464800
# Train Epoch: 197 [25600/45000 (57%)]	Loss: 0.517763
# Train Epoch: 197 [32000/45000 (71%)]	Loss: 0.570386
# Train Epoch: 197 [38400/45000 (85%)]	Loss: 0.473800
# Train Epoch: 197 [44800/45000 (99%)]	Loss: 0.619805
#
# Validation set: Avg. loss: -3.7935, Accuracy: 3823/5000 (76%)
#
# Train Epoch: 198 [0/45000 (0%)]	Loss: 0.648899
# Train Epoch: 198 [6400/45000 (14%)]	Loss: 0.597450
# Train Epoch: 198 [12800/45000 (28%)]	Loss: 0.347640
# Train Epoch: 198 [19200/45000 (43%)]	Loss: 0.423248
# Train Epoch: 198 [25600/45000 (57%)]	Loss: 0.575726
# Train Epoch: 198 [32000/45000 (71%)]	Loss: 0.553635
# Train Epoch: 198 [38400/45000 (85%)]	Loss: 0.724485
# Train Epoch: 198 [44800/45000 (99%)]	Loss: 0.581811
#
# Validation set: Avg. loss: -3.7528, Accuracy: 3800/5000 (76%)
#
# Train Epoch: 199 [0/45000 (0%)]	Loss: 0.741726
# Train Epoch: 199 [6400/45000 (14%)]	Loss: 0.531813
# Train Epoch: 199 [12800/45000 (28%)]	Loss: 0.705244
# Train Epoch: 199 [19200/45000 (43%)]	Loss: 0.491756
# Train Epoch: 199 [25600/45000 (57%)]	Loss: 0.458775
# Train Epoch: 199 [32000/45000 (71%)]	Loss: 0.538270
# Train Epoch: 199 [38400/45000 (85%)]	Loss: 0.524870
# Train Epoch: 199 [44800/45000 (99%)]	Loss: 0.532215
#
# Validation set: Avg. loss: -3.6970, Accuracy: 3848/5000 (77%)
#
# Mounted at /content/gdrive/
#
# Result:
#  OrderedDict([   ('correct', 8015),
#                 ('accuracy', 80.15),
#                 ('run_time', 79.75667464100115),
#                 ('score', 100.0)])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
network = Net().to(device)
#checkpoint = torch.load('./checkpoint/ckpt.pth')
model = torch.load('/content/drive/My Drive/model.pt')
#network.load_state_dict(model)
#network.eval()
config = {
        'lr': 1e-3,
        'num_epochs': 50,
        'batch_size': 64,
        'num_classes': 10,
        'momentum':0.5,
        'regular_constant': 5e-4,
       }
train_dataloader, valid_dataloader, test_dataloader = load_data(config)
if torch.cuda.is_available():
    model.cuda()
test_acc, test_correct, test_total = test(model, test_dataloader, device)
print(test_acc)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /CIFAR10_dataset/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /CIFAR10_dataset/cifar-10-python.tar.gz to /CIFAR10_dataset/
# Files already downloaded and verified
